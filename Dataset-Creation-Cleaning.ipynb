# %% [markdown]
#  Albina Chowdury, Cesar Cisneros, Estelle Hooper, Eva Ruse

# %% [markdown]
# # Dataset Creation & Cleaning
# For our final project, we spent a substantial amount of time creating our datasets `spotify2019` and
# `spotify2020`. First, we web scraped 40 of the [official Spotify top 200 chart webpages](https://spotifycharts.com/regional). Second, we used the Spotify API to gain Spotify-generated audio features of the songs we scraped from the charts. These audio features are numeric scores that rate a song's feature, such as danceability, valence, or loudness.
#
# This notebook documents our process of generating these datasets, explaining the code we wrote and the setbacks we faced.
# <br><br>
# Table of Contents
# <br>
# I. [Introduction: Why did we decide to make our own dataset?](#introduction)
# <br>
# II. [Cleaning Happiness Score Datasets](#cleaning)
# <br>
# III. [Web Scraping Spotify Charts](#scraping)
# <br>
# IV. [Spotify API](#api)
# <br>

# %% [markdown]
# ### I. Introduction: Why did we decide to make our own dataset?<a name="introduction"></a>
# #### Research Question: Is there a relationship between how happy a country is and the music the people of this country listen to?
# When we first asked our main research question at the start of the semester we had planned on using this dataset on Kaggle: [Spotify's Worldwide Daily Song Ranking (2017)](https://www.kaggle.com/edumucelli/spotifys-worldwide-daily-song-ranking).
# It contains the top 200 streamed songs per day each for 54 countries (almost 4,000,000 observations!), directly taken from the [official Spotify Charts website](https://spotifycharts.com/regional). This was the only dataset that we could find containing the top songs of several countries on Spotify.<br><br>
# While we did begin to work with this Kaggle dataset, after becoming more comfortable with pandas and learning about web scraping, we decided that we could make a dataset from the charts ourselves that better suited our research question. By having access to later years' song data (not only 2017), we would be able to answer our research question with more relevant conclusions and do more statistical analyses. For example, in our final project we train a model using 2019 song data to predict a country's happiness score in 2020.

# %% [markdown]
# ### II. Happiness Datasets Cleaning<a name="cleaning"></a>

# %% [markdown]
# Before we could start calling our scraping functions on countries, we needed to identify the top and bottom 10 countries for 2019 and 2020. Below, we clean the Kaggle datasets that compile the happiness scores for these two years.

# %% [markdown]
# We read in the Kaggle dataset that contains the happiness scores for countries in 2019:

# %%
happy2019=pd.read_csv("2019.csv")
happy2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %% [markdown]
# Since we are using countries' happiness scores and a country's top music, we only need to keep the happiness scores for countries that spotify has data on. `allcountries` is a list that contains the names of all the countries that Spotify has data for.

# %%
allcountries=["United States", "United Kingdom", "United Arab Emirates", "Argentina", "Austria", "Australia", "Belgium", "Bulgaria", "Bolivia", "Brazil", "Canada", "Switzerland", "Chile", "Colombia", "Costa Rica", "Cyprus", "Czech Republic", "Germany", "Denmark", "Dominican Republic", "Ecuador", "Estonia", "Egypt", "Spain", "Finland", "France", "Greece", "Guatemala", "Hong Kong", "Honduras", "Hungary", "Indonesia", "Ireland", "Israel", "India", "Iceland", "Italy", "Japan", "Republic of Korea", "Lithuania", "Luxembourg", "Latvia", "Morocco", "Mexico", "Malaysia", "Nicaragua", "Netherlands", "Norway", "New Zealand", "Panama", "Peru", "Philippines", "Poland", "Portugal", "Paraguay", "Romania", "Russia", "Saudi Arabia", "Sweden", "Singapore", "Slovakia", "El Salvador", "Thailand", "Turkey", "Taiwan", "Ukraine", "Uruguay", "Vietnam", "South Africa"
]

# %% [markdown]
# We then subsetted `happy2019` to only include the countries that appear in both the Kaggle 2019 happiness data set and the Spotify Charts website. We also cleaned the column titles for ease of use later.

# %%
cols2019= [x.lower() for x in happy2019.columns] 
cols2019= [x.replace(" ","_") for x in cols2019] 
happy2019.columns=cols2019
countries2019=happy2019.country_or_region.to_numpy()
new=[]
for x in countries2019:
    if x in allcountries:
        new.append(x)
happy2019=happy2019.loc[happy2019['country_or_region'].isin(new)]
happy2019.reset_index(drop=True)
# Out:
#     overall_rank country_or_region  score  gdp_per_capita  social_support  \
# 0              1           Finland  7.769           1.340           1.587
# 1              2           Denmark  7.600           1.383           1.573
# 2              3            Norway  7.554           1.488           1.582
# 3              4           Iceland  7.494           1.380           1.624
# 4              5       Netherlands  7.488           1.396           1.522
# ..           ...               ...    ...             ...             ...
# 63            97          Bulgaria  5.011           1.092           1.513
# 64           106      South Africa  4.722           0.960           1.351
# 65           133           Ukraine  4.332           0.820           1.390
# 66           137             Egypt  4.166           0.913           1.039
# 67           140             India  4.015           0.755           0.765
#
#     healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# 0                     0.986                         0.596       0.153
# 1                     0.996                         0.592       0.252
# 2                     1.028                         0.603       0.271
# 3                     1.026                         0.591       0.354
# 4                     0.999                         0.557       0.322
# ..                      ...                           ...         ...
# 63                    0.815                         0.311       0.081
# 64                    0.469                         0.389       0.130
# 65                    0.739                         0.178       0.187
# 66                    0.644                         0.241       0.076
# 67                    0.588                         0.498       0.200
#
#     perceptions_of_corruption
# 0                       0.393
# 1                       0.410
# 2                       0.341
# 3                       0.118
# 4                       0.298
# ..                        ...
# 63                      0.004
# 64                      0.055
# 65                      0.010
# 66                      0.067
# 67                      0.085
#
# [68 rows x 9 columns]

# %% [markdown]
# We continue to rename columns in the 2019 happiness dataset in order for the 2019 and 2020 datasets to have the same column headings. This helps our data analysis code run on each dataframe

# %%
happy2019.rename({"country_or_region":"country"}, axis="columns", inplace=True)
happy2019.rename({"score":"happiness_score"}, axis="columns", inplace=True)
happy2019.rename({"overall_rank":"rank"}, axis="columns", inplace=True)
happy2019=happy2019[["rank","happiness_score","country"]]

# %% [markdown]
# Another issue we found with scraping the Spotify Charts website was that even if Spotify has data regarding the top songs that a country listens to, they don't always have that data for every day. This issue was especially prominent when we were trying to scrape the countries with the 10 lowest happiness scores. Spotify did not have data available for the entire year of 2019 for countries such as Ukraine and Egypt. To replace these countries, we replaced this country with the next worst happiness score.

# %%
available=pd.read_csv("happy2019.csv", index_col=0)
available_countries=available.country.to_numpy()
happy2019=happy2019.loc[happy2019['country'].isin(available_countries)]
happy2019=happy2019.reset_index(drop=True)

# %% [markdown]
# Below is our cleaned dataset for the top 10 and bottom 10 countries in 2019 in terms of their happiness scores.

# %%
happy2019
# Out:
#     rank  happiness_score             country
# 0      1            7.769             Finland
# 1      2            7.600             Denmark
# 2      3            7.554              Norway
# 3      4            7.494             Iceland
# 4      5            7.488         Netherlands
# 5      6            7.480         Switzerland
# 6      7            7.343              Sweden
# 7      8            7.307         New Zealand
# 8      9            7.278              Canada
# 9     10            7.246             Austria
# 10    66            5.693            Portugal
# 11    69            5.631         Philippines
# 12    76            5.430           Hong Kong
# 13    77            5.425  Dominican Republic
# 14    79            5.373              Turkey
# 15    80            5.339            Malaysia
# 16    82            5.287              Greece
# 17    92            5.192           Indonesia
# 18    94            5.175             Vietnam
# 19   106            4.722        South Africa

# %% [markdown]
# Next we go through the same process to create the happiness score dataset for countries in 2020.

# %%
happy2020=pd.read_csv("happiness2020.csv")
happy2020['rank']=np.arange(1,len(happy2020)+1)
happy2020.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# 3              10.772559        0.974670                73.000000
# 4              11.087804        0.952487                73.200783
#
#    Freedom to make life choices  ...  Perceptions of corruption  \
# 0                      0.949172  ...                   0.195445
# 1                      0.951444  ...                   0.168489
# 2                      0.921337  ...                   0.303728
# 3                      0.948892  ...                   0.711710
# 4                      0.955750  ...                   0.263218
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                  1.972317                          1.285190
# 1                  1.972317                          1.326949
# 2                  1.972317                          1.390774
# 3                  1.972317                          1.326502
# 4                  1.972317                          1.424207
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                      1.499526                               0.961271
# 1                      1.503449                               0.979333
# 2                      1.472403                               1.040533
# 3                      1.547567                               1.000843
# 4                      1.495173                               1.008072
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.662317                  0.159670
# 1                                    0.665040                  0.242793
# 2                                    0.628954                  0.269056
# 3                                    0.661981                  0.362330
# 4                                    0.670201                  0.287985
#
#    Explained by: Perceptions of corruption  Dystopia + residual  rank
# 0                                 0.477857             2.762835     1
# 1                                 0.495260             2.432741     2
# 2                                 0.407946             2.350267     3
# 3                                 0.144541             2.460688     4
# 4                                 0.434101             2.168266     5
#
# [5 rows x 21 columns]

# %%
cols2020= [x.lower() for x in happy2020.columns] 
cols2020= [x.replace(" ","_") for x in cols2020] 
happy2020.columns=cols2020
countries2020=happy2020.country_name.to_numpy()
new=[]
for x in countries2020:
    if x in allcountries:
        new.append(x)
topbot2020=new[:10]+new[-10:]
happy2020=happy2020.loc[happy2020['country_name'].isin(topbot2020)]
happy2020.rename({"country_name":"country"}, axis="columns", inplace=True)
happy2020.rename({"ladder_score":"happiness_score"}, axis="columns", inplace=True)

happy2020=happy2020[["rank","happiness_score","country"]]

# %%
happy2020
# Out:
#      rank  happiness_score       country
# 0       1           7.8087       Finland
# 1       2           7.6456       Denmark
# 2       3           7.5599   Switzerland
# 3       4           7.5045       Iceland
# 4       5           7.4880        Norway
# 5       6           7.4489   Netherlands
# 6       7           7.3535        Sweden
# 7       8           7.2996   New Zealand
# 8       9           7.2942       Austria
# 9      10           7.2375    Luxembourg
# 81     82           5.3843      Malaysia
# 82     83           5.3535       Vietnam
# 83     84           5.2856     Indonesia
# 92     93           5.1318        Turkey
# 95     96           5.1015      Bulgaria
# 96     97           5.0948       Morocco
# 108   109           4.8141  South Africa
# 122   123           4.5607       Ukraine
# 137   138           4.1514         Egypt
# 143   144           3.5733         India

# %% [markdown]
# We still had the same issue that Spotify does not provide a full year's worth of data regarding a country's top songs per day, so we replace countries for which  we don't have a complete set of data.

# %%
available=pd.read_csv("happy2020.csv", index_col=0)
available_countries=available.country.to_numpy()
happy2020=happy2020.loc[happy2020['country'].isin(available_countries)]
happy2020=happy2020.reset_index(drop=True)

# %%
happy2020
# Out:
#     rank  happiness_score       country
# 0      1           7.8087       Finland
# 1      2           7.6456       Denmark
# 2      3           7.5599   Switzerland
# 3      4           7.5045       Iceland
# 4      5           7.4880        Norway
# 5      6           7.4489   Netherlands
# 6      7           7.3535        Sweden
# 7      8           7.2996   New Zealand
# 8      9           7.2942       Austria
# 9     82           5.3843      Malaysia
# 10    83           5.3535       Vietnam
# 11    84           5.2856     Indonesia
# 12    93           5.1318        Turkey
# 13    97           5.0948       Morocco
# 14   109           4.8141  South Africa
# 15   138           4.1514         Egypt
# 16   144           3.5733         India

# %% [markdown]
# We saved both datasets as CSV files so we could continue to use them in our main analysis.

# %%
happy2019.to_csv("happy2019.csv")

# %%
happy2020.to_csv("happy2020.csv")

# %% [markdown]
# ### III. Web Scraping <a name="scraping"></a>

# %% [markdown]
# On a page on https://spotifycharts.com , Spotify allows users to select a date and a country to see a table of the "Top 200", a ranking of the top 200 songs by number of streams (not "Viral 50", which ranks songs by user-sharing). The following functions will create a pandas DataFrame by scraping the table from this webpage. Below is a screenshot of the Spotify Charts website that shows the top 10 songs across the world on April 26th, 2021.

# %% [markdown]
# <img src="spotify_chart.png" width="1000">

# %%
#relevant imports
import requests #package for http requests
import bs4 #package for html parsing
import numpy as np
import pandas as pd 
from datetime import timedelta, date
import cloudscraper #for bypassing Spotify cloudflare protection. explained in section 2.5

# %% [markdown]
# In order to access the top songs for a certain country on the Spotify Charts website, a user has to select the country from the drop-down menu, which loads a new page. The day that the user is looking at also loads a new page. Therefore, looking at a certain country's top songs for an entire year would generate around 365 links. Since we looked at 20 countries for both 2019 and 2020, we needed 365 links for 40 countries. Defining functions that created and saved these links helped simplify this process. After looping through each link for a country, we were able to get the information listed on each page that a link was connected to.
#
# We created the three functions below, `create_links_2019`, `create_links_2020`, and `daterange`, to get the links for each country more effectively. `daterange(start_date, end_date)` acts as a helper method to  `create_links_2019` and `create_links_2020`.

# %% [markdown]
# When`create_links_2019` is called on a country, it returns a list of links. These links are connected to the Spotify Charts website that has the top 200 songs for a certain day. The list only contains links to the top 200 songs in a country between January 1st, 2019 and December 31st, 2019. This method was necessary since we created separate datasets for Spotify data from 2019 and Spotify data from 2020.

# %%
# It creates the list of links in 2019 we will web scrape from.
def create_links_2019(country):
    '''
    returns: an array of strings, which are 365 links to spotify charts for each day in 2020 for a specified country.
    parameter: a string. a country's ISO Alpha-2 country abbreviation. These are 2-letter internationally recognized codes.
    https://www.nationsonline.org/oneworld/country_code_list.html for a full list of ISO Alpha-2 country codes.
    eg. to get 365 links for the united states, call create_links_2019('us')
    '''
    start_date = date(2019, 1, 1)
    end_date = date(2019,12,31)
    links = []
    for single_date in daterange(start_date, end_date):
        links.append('https://spotifycharts.com/regional/' + country + '/daily/' + single_date.strftime("%Y-%m-%d"))
    return(links)

# %% [markdown]
# When`create_links_2020` is called on a country, it does the exact same thing as `create_links_2019` except that the returned list only contains links to the top 200 songs in a country between January 1st, 2020 and December 31st, 2020. This method was called only when we were creating the Spotify dataset that only contained information regarding what music countries in 2020 listened to.

# %%
def create_links_2020(country):
    '''
    returns: an array of strings, which are 364 links to spotify charts for each day in 2019 for a specified country.
    parameter: a string. a country's ISO Alpha-2 country abbreviation. These are 2-letter internationally recognized codes.
    https://www.nationsonline.org/oneworld/country_code_list.html for a full list of ISO Alpha-2 country codes.
    eg. to get 365 links for the united states, call create_links_2020('us')
    '''
    start_date = date(2020, 1, 1)
    end_date = date(2020,12,31)
    links = []
    for single_date in daterange(start_date, end_date):
        links.append('https://spotifycharts.com/regional/' + country + '/daily/' + single_date.strftime("%Y-%m-%d"))
    return(links)

# %% [markdown]
# `daterange(start_date, end_date)` returns a daterange object that is looped through in either `create_links_2019` or `create_links_2020` in order to append a link for every day of the year.

# %%
def daterange(start_date, end_date):
    '''
    helper function for create_links_2019 and create_links_2020
    returns: daterange object.
    parameters: a start date and end date in "%Y-%m-%d" format.
    '''
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

# %% [markdown]
# Below, we call `create_links_2019` on the United States to demonstrate:

# %%
links_us=create_links_2019('us')

start_date = date(2019, 1, 1)
end_date = date(2019,12,31)
index=0
for single_date in daterange(start_date, end_date):
        print('Link to top 200 songs on ' + single_date.strftime("%Y-%m-%d")+': '+links_us[index])
        index=index+1
# Out:
# Link to top 200 songs on 2019-01-01: https://spotifycharts.com/regional/us/daily/2019-01-01
# Link to top 200 songs on 2019-01-02: https://spotifycharts.com/regional/us/daily/2019-01-02
# Link to top 200 songs on 2019-01-03: https://spotifycharts.com/regional/us/daily/2019-01-03
# Link to top 200 songs on 2019-01-04: https://spotifycharts.com/regional/us/daily/2019-01-04
# Link to top 200 songs on 2019-01-05: https://spotifycharts.com/regional/us/daily/2019-01-05
# Link to top 200 songs on 2019-01-06: https://spotifycharts.com/regional/us/daily/2019-01-06
# Link to top 200 songs on 2019-01-07: https://spotifycharts.com/regional/us/daily/2019-01-07
# Link to top 200 songs on 2019-01-08: https://spotifycharts.com/regional/us/daily/2019-01-08
# Link to top 200 songs on 2019-01-09: https://spotifycharts.com/regional/us/daily/2019-01-09
# Link to top 200 songs on 2019-01-10: https://spotifycharts.com/regional/us/daily/2019-01-10
# Link to top 200 songs on 2019-01-11: https://spotifycharts.com/regional/us/daily/2019-01-11
# Link to top 200 songs on 2019-01-12: https://spotifycharts.com/regional/us/daily/2019-01-12
# Link to top 200 songs on 2019-01-13: https://spotifycharts.com/regional/us/daily/2019-01-13
# Link to top 200 songs on 2019-01-14: https://spotifycharts.com/regional/us/daily/2019-01-14
# Link to top 200 songs on 2019-01-15: https://spotifycharts.com/regional/us/daily/2019-01-15
# Link to top 200 songs on 2019-01-16: https://spotifycharts.com/regional/us/daily/2019-01-16
# Link to top 200 songs on 2019-01-17: https://spotifycharts.com/regional/us/daily/2019-01-17
# Link to top 200 songs on 2019-01-18: https://spotifycharts.com/regional/us/daily/2019-01-18
# Link to top 200 songs on 2019-01-19: https://spotifycharts.com/regional/us/daily/2019-01-19
# Link to top 200 songs on 2019-01-20: https://spotifycharts.com/regional/us/daily/2019-01-20
# Link to top 200 songs on 2019-01-21: https://spotifycharts.com/regional/us/daily/2019-01-21
# Link to top 200 songs on 2019-01-22: https://spotifycharts.com/regional/us/daily/2019-01-22
# Link to top 200 songs on 2019-01-23: https://spotifycharts.com/regional/us/daily/2019-01-23
# Link to top 200 songs on 2019-01-24: https://spotifycharts.com/regional/us/daily/2019-01-24
# Link to top 200 songs on 2019-01-25: https://spotifycharts.com/regional/us/daily/2019-01-25
# Link to top 200 songs on 2019-01-26: https://spotifycharts.com/regional/us/daily/2019-01-26
# Link to top 200 songs on 2019-01-27: https://spotifycharts.com/regional/us/daily/2019-01-27
# Link to top 200 songs on 2019-01-28: https://spotifycharts.com/regional/us/daily/2019-01-28
# Link to top 200 songs on 2019-01-29: https://spotifycharts.com/regional/us/daily/2019-01-29
# Link to top 200 songs on 2019-01-30: https://spotifycharts.com/regional/us/daily/2019-01-30
# Link to top 200 songs on 2019-01-31: https://spotifycharts.com/regional/us/daily/2019-01-31
# Link to top 200 songs on 2019-02-01: https://spotifycharts.com/regional/us/daily/2019-02-01
# Link to top 200 songs on 2019-02-02: https://spotifycharts.com/regional/us/daily/2019-02-02
# Link to top 200 songs on 2019-02-03: https://spotifycharts.com/regional/us/daily/2019-02-03
# Link to top 200 songs on 2019-02-04: https://spotifycharts.com/regional/us/daily/2019-02-04
# Link to top 200 songs on 2019-02-05: https://spotifycharts.com/regional/us/daily/2019-02-05
# Link to top 200 songs on 2019-02-06: https://spotifycharts.com/regional/us/daily/2019-02-06
# Link to top 200 songs on 2019-02-07: https://spotifycharts.com/regional/us/daily/2019-02-07
# Link to top 200 songs on 2019-02-08: https://spotifycharts.com/regional/us/daily/2019-02-08
# Link to top 200 songs on 2019-02-09: https://spotifycharts.com/regional/us/daily/2019-02-09
# Link to top 200 songs on 2019-02-10: https://spotifycharts.com/regional/us/daily/2019-02-10
# Link to top 200 songs on 2019-02-11: https://spotifycharts.com/regional/us/daily/2019-02-11
# Link to top 200 songs on 2019-02-12: https://spotifycharts.com/regional/us/daily/2019-02-12
# Link to top 200 songs on 2019-02-13: https://spotifycharts.com/regional/us/daily/2019-02-13
# Link to top 200 songs on 2019-02-14: https://spotifycharts.com/regional/us/daily/2019-02-14
# Link to top 200 songs on 2019-02-15: https://spotifycharts.com/regional/us/daily/2019-02-15
# Link to top 200 songs on 2019-02-16: https://spotifycharts.com/regional/us/daily/2019-02-16
# Link to top 200 songs on 2019-02-17: https://spotifycharts.com/regional/us/daily/2019-02-17
# Link to top 200 songs on 2019-02-18: https://spotifycharts.com/regional/us/daily/2019-02-18
# Link to top 200 songs on 2019-02-19: https://spotifycharts.com/regional/us/daily/2019-02-19
# Link to top 200 songs on 2019-02-20: https://spotifycharts.com/regional/us/daily/2019-02-20
# Link to top 200 songs on 2019-02-21: https://spotifycharts.com/regional/us/daily/2019-02-21
# Link to top 200 songs on 2019-02-22: https://spotifycharts.com/regional/us/daily/2019-02-22
# Link to top 200 songs on 2019-02-23: https://spotifycharts.com/regional/us/daily/2019-02-23
# Link to top 200 songs on 2019-02-24: https://spotifycharts.com/regional/us/daily/2019-02-24
# Link to top 200 songs on 2019-02-25: https://spotifycharts.com/regional/us/daily/2019-02-25
# Link to top 200 songs on 2019-02-26: https://spotifycharts.com/regional/us/daily/2019-02-26
# Link to top 200 songs on 2019-02-27: https://spotifycharts.com/regional/us/daily/2019-02-27
# Link to top 200 songs on 2019-02-28: https://spotifycharts.com/regional/us/daily/2019-02-28
# Link to top 200 songs on 2019-03-01: https://spotifycharts.com/regional/us/daily/2019-03-01
# Link to top 200 songs on 2019-03-02: https://spotifycharts.com/regional/us/daily/2019-03-02
# Link to top 200 songs on 2019-03-03: https://spotifycharts.com/regional/us/daily/2019-03-03
# Link to top 200 songs on 2019-03-04: https://spotifycharts.com/regional/us/daily/2019-03-04
# Link to top 200 songs on 2019-03-05: https://spotifycharts.com/regional/us/daily/2019-03-05
# Link to top 200 songs on 2019-03-06: https://spotifycharts.com/regional/us/daily/2019-03-06
# Link to top 200 songs on 2019-03-07: https://spotifycharts.com/regional/us/daily/2019-03-07
# Link to top 200 songs on 2019-03-08: https://spotifycharts.com/regional/us/daily/2019-03-08
# Link to top 200 songs on 2019-03-09: https://spotifycharts.com/regional/us/daily/2019-03-09
# Link to top 200 songs on 2019-03-10: https://spotifycharts.com/regional/us/daily/2019-03-10
# Link to top 200 songs on 2019-03-11: https://spotifycharts.com/regional/us/daily/2019-03-11
# Link to top 200 songs on 2019-03-12: https://spotifycharts.com/regional/us/daily/2019-03-12
# Link to top 200 songs on 2019-03-13: https://spotifycharts.com/regional/us/daily/2019-03-13
# Link to top 200 songs on 2019-03-14: https://spotifycharts.com/regional/us/daily/2019-03-14
# Link to top 200 songs on 2019-03-15: https://spotifycharts.com/regional/us/daily/2019-03-15
# Link to top 200 songs on 2019-03-16: https://spotifycharts.com/regional/us/daily/2019-03-16
# Link to top 200 songs on 2019-03-17: https://spotifycharts.com/regional/us/daily/2019-03-17
# Link to top 200 songs on 2019-03-18: https://spotifycharts.com/regional/us/daily/2019-03-18
# Link to top 200 songs on 2019-03-19: https://spotifycharts.com/regional/us/daily/2019-03-19
# Link to top 200 songs on 2019-03-20: https://spotifycharts.com/regional/us/daily/2019-03-20
# Link to top 200 songs on 2019-03-21: https://spotifycharts.com/regional/us/daily/2019-03-21
# Link to top 200 songs on 2019-03-22: https://spotifycharts.com/regional/us/daily/2019-03-22
# Link to top 200 songs on 2019-03-23: https://spotifycharts.com/regional/us/daily/2019-03-23
# Link to top 200 songs on 2019-03-24: https://spotifycharts.com/regional/us/daily/2019-03-24
# Link to top 200 songs on 2019-03-25: https://spotifycharts.com/regional/us/daily/2019-03-25
# Link to top 200 songs on 2019-03-26: https://spotifycharts.com/regional/us/daily/2019-03-26
# Link to top 200 songs on 2019-03-27: https://spotifycharts.com/regional/us/daily/2019-03-27
# Link to top 200 songs on 2019-03-28: https://spotifycharts.com/regional/us/daily/2019-03-28
# Link to top 200 songs on 2019-03-29: https://spotifycharts.com/regional/us/daily/2019-03-29
# Link to top 200 songs on 2019-03-30: https://spotifycharts.com/regional/us/daily/2019-03-30
# Link to top 200 songs on 2019-03-31: https://spotifycharts.com/regional/us/daily/2019-03-31
# Link to top 200 songs on 2019-04-01: https://spotifycharts.com/regional/us/daily/2019-04-01
# Link to top 200 songs on 2019-04-02: https://spotifycharts.com/regional/us/daily/2019-04-02
# Link to top 200 songs on 2019-04-03: https://spotifycharts.com/regional/us/daily/2019-04-03
# Link to top 200 songs on 2019-04-04: https://spotifycharts.com/regional/us/daily/2019-04-04
# Link to top 200 songs on 2019-04-05: https://spotifycharts.com/regional/us/daily/2019-04-05
# Link to top 200 songs on 2019-04-06: https://spotifycharts.com/regional/us/daily/2019-04-06
# Link to top 200 songs on 2019-04-07: https://spotifycharts.com/regional/us/daily/2019-04-07
# Link to top 200 songs on 2019-04-08: https://spotifycharts.com/regional/us/daily/2019-04-08
# Link to top 200 songs on 2019-04-09: https://spotifycharts.com/regional/us/daily/2019-04-09
# Link to top 200 songs on 2019-04-10: https://spotifycharts.com/regional/us/daily/2019-04-10
# Link to top 200 songs on 2019-04-11: https://spotifycharts.com/regional/us/daily/2019-04-11
# Link to top 200 songs on 2019-04-12: https://spotifycharts.com/regional/us/daily/2019-04-12
# Link to top 200 songs on 2019-04-13: https://spotifycharts.com/regional/us/daily/2019-04-13
# Link to top 200 songs on 2019-04-14: https://spotifycharts.com/regional/us/daily/2019-04-14
# Link to top 200 songs on 2019-04-15: https://spotifycharts.com/regional/us/daily/2019-04-15
# Link to top 200 songs on 2019-04-16: https://spotifycharts.com/regional/us/daily/2019-04-16
# Link to top 200 songs on 2019-04-17: https://spotifycharts.com/regional/us/daily/2019-04-17
# Link to top 200 songs on 2019-04-18: https://spotifycharts.com/regional/us/daily/2019-04-18
# Link to top 200 songs on 2019-04-19: https://spotifycharts.com/regional/us/daily/2019-04-19
# Link to top 200 songs on 2019-04-20: https://spotifycharts.com/regional/us/daily/2019-04-20
# Link to top 200 songs on 2019-04-21: https://spotifycharts.com/regional/us/daily/2019-04-21
# Link to top 200 songs on 2019-04-22: https://spotifycharts.com/regional/us/daily/2019-04-22
# Link to top 200 songs on 2019-04-23: https://spotifycharts.com/regional/us/daily/2019-04-23
# Link to top 200 songs on 2019-04-24: https://spotifycharts.com/regional/us/daily/2019-04-24
# Link to top 200 songs on 2019-04-25: https://spotifycharts.com/regional/us/daily/2019-04-25
# Link to top 200 songs on 2019-04-26: https://spotifycharts.com/regional/us/daily/2019-04-26
# Link to top 200 songs on 2019-04-27: https://spotifycharts.com/regional/us/daily/2019-04-27
# Link to top 200 songs on 2019-04-28: https://spotifycharts.com/regional/us/daily/2019-04-28
# Link to top 200 songs on 2019-04-29: https://spotifycharts.com/regional/us/daily/2019-04-29
# Link to top 200 songs on 2019-04-30: https://spotifycharts.com/regional/us/daily/2019-04-30
# Link to top 200 songs on 2019-05-01: https://spotifycharts.com/regional/us/daily/2019-05-01
# Link to top 200 songs on 2019-05-02: https://spotifycharts.com/regional/us/daily/2019-05-02
# Link to top 200 songs on 2019-05-03: https://spotifycharts.com/regional/us/daily/2019-05-03
# Link to top 200 songs on 2019-05-04: https://spotifycharts.com/regional/us/daily/2019-05-04
# Link to top 200 songs on 2019-05-05: https://spotifycharts.com/regional/us/daily/2019-05-05
# Link to top 200 songs on 2019-05-06: https://spotifycharts.com/regional/us/daily/2019-05-06
# Link to top 200 songs on 2019-05-07: https://spotifycharts.com/regional/us/daily/2019-05-07
# Link to top 200 songs on 2019-05-08: https://spotifycharts.com/regional/us/daily/2019-05-08
# Link to top 200 songs on 2019-05-09: https://spotifycharts.com/regional/us/daily/2019-05-09
# Link to top 200 songs on 2019-05-10: https://spotifycharts.com/regional/us/daily/2019-05-10
# Link to top 200 songs on 2019-05-11: https://spotifycharts.com/regional/us/daily/2019-05-11
# Link to top 200 songs on 2019-05-12: https://spotifycharts.com/regional/us/daily/2019-05-12
# Link to top 200 songs on 2019-05-13: https://spotifycharts.com/regional/us/daily/2019-05-13
# Link to top 200 songs on 2019-05-14: https://spotifycharts.com/regional/us/daily/2019-05-14
# Link to top 200 songs on 2019-05-15: https://spotifycharts.com/regional/us/daily/2019-05-15
# Link to top 200 songs on 2019-05-16: https://spotifycharts.com/regional/us/daily/2019-05-16
# Link to top 200 songs on 2019-05-17: https://spotifycharts.com/regional/us/daily/2019-05-17
# Link to top 200 songs on 2019-05-18: https://spotifycharts.com/regional/us/daily/2019-05-18
# Link to top 200 songs on 2019-05-19: https://spotifycharts.com/regional/us/daily/2019-05-19
# Link to top 200 songs on 2019-05-20: https://spotifycharts.com/regional/us/daily/2019-05-20
# Link to top 200 songs on 2019-05-21: https://spotifycharts.com/regional/us/daily/2019-05-21
# Link to top 200 songs on 2019-05-22: https://spotifycharts.com/regional/us/daily/2019-05-22
# Link to top 200 songs on 2019-05-23: https://spotifycharts.com/regional/us/daily/2019-05-23
# Link to top 200 songs on 2019-05-24: https://spotifycharts.com/regional/us/daily/2019-05-24
# Link to top 200 songs on 2019-05-25: https://spotifycharts.com/regional/us/daily/2019-05-25
# Link to top 200 songs on 2019-05-26: https://spotifycharts.com/regional/us/daily/2019-05-26
# Link to top 200 songs on 2019-05-27: https://spotifycharts.com/regional/us/daily/2019-05-27
# Link to top 200 songs on 2019-05-28: https://spotifycharts.com/regional/us/daily/2019-05-28
# Link to top 200 songs on 2019-05-29: https://spotifycharts.com/regional/us/daily/2019-05-29
# Link to top 200 songs on 2019-05-30: https://spotifycharts.com/regional/us/daily/2019-05-30
# Link to top 200 songs on 2019-05-31: https://spotifycharts.com/regional/us/daily/2019-05-31
# Link to top 200 songs on 2019-06-01: https://spotifycharts.com/regional/us/daily/2019-06-01
# Link to top 200 songs on 2019-06-02: https://spotifycharts.com/regional/us/daily/2019-06-02
# Link to top 200 songs on 2019-06-03: https://spotifycharts.com/regional/us/daily/2019-06-03
# Link to top 200 songs on 2019-06-04: https://spotifycharts.com/regional/us/daily/2019-06-04
# Link to top 200 songs on 2019-06-05: https://spotifycharts.com/regional/us/daily/2019-06-05
# Link to top 200 songs on 2019-06-06: https://spotifycharts.com/regional/us/daily/2019-06-06
# Link to top 200 songs on 2019-06-07: https://spotifycharts.com/regional/us/daily/2019-06-07
# Link to top 200 songs on 2019-06-08: https://spotifycharts.com/regional/us/daily/2019-06-08
# Link to top 200 songs on 2019-06-09: https://spotifycharts.com/regional/us/daily/2019-06-09
# Link to top 200 songs on 2019-06-10: https://spotifycharts.com/regional/us/daily/2019-06-10
# Link to top 200 songs on 2019-06-11: https://spotifycharts.com/regional/us/daily/2019-06-11
# Link to top 200 songs on 2019-06-12: https://spotifycharts.com/regional/us/daily/2019-06-12
# Link to top 200 songs on 2019-06-13: https://spotifycharts.com/regional/us/daily/2019-06-13
# Link to top 200 songs on 2019-06-14: https://spotifycharts.com/regional/us/daily/2019-06-14
# Link to top 200 songs on 2019-06-15: https://spotifycharts.com/regional/us/daily/2019-06-15
# Link to top 200 songs on 2019-06-16: https://spotifycharts.com/regional/us/daily/2019-06-16
# Link to top 200 songs on 2019-06-17: https://spotifycharts.com/regional/us/daily/2019-06-17
# Link to top 200 songs on 2019-06-18: https://spotifycharts.com/regional/us/daily/2019-06-18
# Link to top 200 songs on 2019-06-19: https://spotifycharts.com/regional/us/daily/2019-06-19
# Link to top 200 songs on 2019-06-20: https://spotifycharts.com/regional/us/daily/2019-06-20
# Link to top 200 songs on 2019-06-21: https://spotifycharts.com/regional/us/daily/2019-06-21
# Link to top 200 songs on 2019-06-22: https://spotifycharts.com/regional/us/daily/2019-06-22
# Link to top 200 songs on 2019-06-23: https://spotifycharts.com/regional/us/daily/2019-06-23
# Link to top 200 songs on 2019-06-24: https://spotifycharts.com/regional/us/daily/2019-06-24
# Link to top 200 songs on 2019-06-25: https://spotifycharts.com/regional/us/daily/2019-06-25
# Link to top 200 songs on 2019-06-26: https://spotifycharts.com/regional/us/daily/2019-06-26
# Link to top 200 songs on 2019-06-27: https://spotifycharts.com/regional/us/daily/2019-06-27
# Link to top 200 songs on 2019-06-28: https://spotifycharts.com/regional/us/daily/2019-06-28
# Link to top 200 songs on 2019-06-29: https://spotifycharts.com/regional/us/daily/2019-06-29
# Link to top 200 songs on 2019-06-30: https://spotifycharts.com/regional/us/daily/2019-06-30
# Link to top 200 songs on 2019-07-01: https://spotifycharts.com/regional/us/daily/2019-07-01
# Link to top 200 songs on 2019-07-02: https://spotifycharts.com/regional/us/daily/2019-07-02
# Link to top 200 songs on 2019-07-03: https://spotifycharts.com/regional/us/daily/2019-07-03
# Link to top 200 songs on 2019-07-04: https://spotifycharts.com/regional/us/daily/2019-07-04
# Link to top 200 songs on 2019-07-05: https://spotifycharts.com/regional/us/daily/2019-07-05
# Link to top 200 songs on 2019-07-06: https://spotifycharts.com/regional/us/daily/2019-07-06
# Link to top 200 songs on 2019-07-07: https://spotifycharts.com/regional/us/daily/2019-07-07
# Link to top 200 songs on 2019-07-08: https://spotifycharts.com/regional/us/daily/2019-07-08
# Link to top 200 songs on 2019-07-09: https://spotifycharts.com/regional/us/daily/2019-07-09
# Link to top 200 songs on 2019-07-10: https://spotifycharts.com/regional/us/daily/2019-07-10
# Link to top 200 songs on 2019-07-11: https://spotifycharts.com/regional/us/daily/2019-07-11
# Link to top 200 songs on 2019-07-12: https://spotifycharts.com/regional/us/daily/2019-07-12
# Link to top 200 songs on 2019-07-13: https://spotifycharts.com/regional/us/daily/2019-07-13
# Link to top 200 songs on 2019-07-14: https://spotifycharts.com/regional/us/daily/2019-07-14
# Link to top 200 songs on 2019-07-15: https://spotifycharts.com/regional/us/daily/2019-07-15
# Link to top 200 songs on 2019-07-16: https://spotifycharts.com/regional/us/daily/2019-07-16
# Link to top 200 songs on 2019-07-17: https://spotifycharts.com/regional/us/daily/2019-07-17
# Link to top 200 songs on 2019-07-18: https://spotifycharts.com/regional/us/daily/2019-07-18
# Link to top 200 songs on 2019-07-19: https://spotifycharts.com/regional/us/daily/2019-07-19
# Link to top 200 songs on 2019-07-20: https://spotifycharts.com/regional/us/daily/2019-07-20
# Link to top 200 songs on 2019-07-21: https://spotifycharts.com/regional/us/daily/2019-07-21
# Link to top 200 songs on 2019-07-22: https://spotifycharts.com/regional/us/daily/2019-07-22
# Link to top 200 songs on 2019-07-23: https://spotifycharts.com/regional/us/daily/2019-07-23
# Link to top 200 songs on 2019-07-24: https://spotifycharts.com/regional/us/daily/2019-07-24
# Link to top 200 songs on 2019-07-25: https://spotifycharts.com/regional/us/daily/2019-07-25
# Link to top 200 songs on 2019-07-26: https://spotifycharts.com/regional/us/daily/2019-07-26
# Link to top 200 songs on 2019-07-27: https://spotifycharts.com/regional/us/daily/2019-07-27
# Link to top 200 songs on 2019-07-28: https://spotifycharts.com/regional/us/daily/2019-07-28
# Link to top 200 songs on 2019-07-29: https://spotifycharts.com/regional/us/daily/2019-07-29
# Link to top 200 songs on 2019-07-30: https://spotifycharts.com/regional/us/daily/2019-07-30
# Link to top 200 songs on 2019-07-31: https://spotifycharts.com/regional/us/daily/2019-07-31
# Link to top 200 songs on 2019-08-01: https://spotifycharts.com/regional/us/daily/2019-08-01
# Link to top 200 songs on 2019-08-02: https://spotifycharts.com/regional/us/daily/2019-08-02
# Link to top 200 songs on 2019-08-03: https://spotifycharts.com/regional/us/daily/2019-08-03
# Link to top 200 songs on 2019-08-04: https://spotifycharts.com/regional/us/daily/2019-08-04
# Link to top 200 songs on 2019-08-05: https://spotifycharts.com/regional/us/daily/2019-08-05
# Link to top 200 songs on 2019-08-06: https://spotifycharts.com/regional/us/daily/2019-08-06
# Link to top 200 songs on 2019-08-07: https://spotifycharts.com/regional/us/daily/2019-08-07
# Link to top 200 songs on 2019-08-08: https://spotifycharts.com/regional/us/daily/2019-08-08
# Link to top 200 songs on 2019-08-09: https://spotifycharts.com/regional/us/daily/2019-08-09
# Link to top 200 songs on 2019-08-10: https://spotifycharts.com/regional/us/daily/2019-08-10
# Link to top 200 songs on 2019-08-11: https://spotifycharts.com/regional/us/daily/2019-08-11
# Link to top 200 songs on 2019-08-12: https://spotifycharts.com/regional/us/daily/2019-08-12
# Link to top 200 songs on 2019-08-13: https://spotifycharts.com/regional/us/daily/2019-08-13
# Link to top 200 songs on 2019-08-14: https://spotifycharts.com/regional/us/daily/2019-08-14
# Link to top 200 songs on 2019-08-15: https://spotifycharts.com/regional/us/daily/2019-08-15
# Link to top 200 songs on 2019-08-16: https://spotifycharts.com/regional/us/daily/2019-08-16
# Link to top 200 songs on 2019-08-17: https://spotifycharts.com/regional/us/daily/2019-08-17
# Link to top 200 songs on 2019-08-18: https://spotifycharts.com/regional/us/daily/2019-08-18
# Link to top 200 songs on 2019-08-19: https://spotifycharts.com/regional/us/daily/2019-08-19
# Link to top 200 songs on 2019-08-20: https://spotifycharts.com/regional/us/daily/2019-08-20
# Link to top 200 songs on 2019-08-21: https://spotifycharts.com/regional/us/daily/2019-08-21
# Link to top 200 songs on 2019-08-22: https://spotifycharts.com/regional/us/daily/2019-08-22
# Link to top 200 songs on 2019-08-23: https://spotifycharts.com/regional/us/daily/2019-08-23
# Link to top 200 songs on 2019-08-24: https://spotifycharts.com/regional/us/daily/2019-08-24
# Link to top 200 songs on 2019-08-25: https://spotifycharts.com/regional/us/daily/2019-08-25
# Link to top 200 songs on 2019-08-26: https://spotifycharts.com/regional/us/daily/2019-08-26
# Link to top 200 songs on 2019-08-27: https://spotifycharts.com/regional/us/daily/2019-08-27
# Link to top 200 songs on 2019-08-28: https://spotifycharts.com/regional/us/daily/2019-08-28
# Link to top 200 songs on 2019-08-29: https://spotifycharts.com/regional/us/daily/2019-08-29
# Link to top 200 songs on 2019-08-30: https://spotifycharts.com/regional/us/daily/2019-08-30
# Link to top 200 songs on 2019-08-31: https://spotifycharts.com/regional/us/daily/2019-08-31
# Link to top 200 songs on 2019-09-01: https://spotifycharts.com/regional/us/daily/2019-09-01
# Link to top 200 songs on 2019-09-02: https://spotifycharts.com/regional/us/daily/2019-09-02
# Link to top 200 songs on 2019-09-03: https://spotifycharts.com/regional/us/daily/2019-09-03
# Link to top 200 songs on 2019-09-04: https://spotifycharts.com/regional/us/daily/2019-09-04
# Link to top 200 songs on 2019-09-05: https://spotifycharts.com/regional/us/daily/2019-09-05
# Link to top 200 songs on 2019-09-06: https://spotifycharts.com/regional/us/daily/2019-09-06
# Link to top 200 songs on 2019-09-07: https://spotifycharts.com/regional/us/daily/2019-09-07
# Link to top 200 songs on 2019-09-08: https://spotifycharts.com/regional/us/daily/2019-09-08
# Link to top 200 songs on 2019-09-09: https://spotifycharts.com/regional/us/daily/2019-09-09
# Link to top 200 songs on 2019-09-10: https://spotifycharts.com/regional/us/daily/2019-09-10
# Link to top 200 songs on 2019-09-11: https://spotifycharts.com/regional/us/daily/2019-09-11
# Link to top 200 songs on 2019-09-12: https://spotifycharts.com/regional/us/daily/2019-09-12
# Link to top 200 songs on 2019-09-13: https://spotifycharts.com/regional/us/daily/2019-09-13
# Link to top 200 songs on 2019-09-14: https://spotifycharts.com/regional/us/daily/2019-09-14
# Link to top 200 songs on 2019-09-15: https://spotifycharts.com/regional/us/daily/2019-09-15
# Link to top 200 songs on 2019-09-16: https://spotifycharts.com/regional/us/daily/2019-09-16
# Link to top 200 songs on 2019-09-17: https://spotifycharts.com/regional/us/daily/2019-09-17
# Link to top 200 songs on 2019-09-18: https://spotifycharts.com/regional/us/daily/2019-09-18
# Link to top 200 songs on 2019-09-19: https://spotifycharts.com/regional/us/daily/2019-09-19
# Link to top 200 songs on 2019-09-20: https://spotifycharts.com/regional/us/daily/2019-09-20
# Link to top 200 songs on 2019-09-21: https://spotifycharts.com/regional/us/daily/2019-09-21
# Link to top 200 songs on 2019-09-22: https://spotifycharts.com/regional/us/daily/2019-09-22
# Link to top 200 songs on 2019-09-23: https://spotifycharts.com/regional/us/daily/2019-09-23
# Link to top 200 songs on 2019-09-24: https://spotifycharts.com/regional/us/daily/2019-09-24
# Link to top 200 songs on 2019-09-25: https://spotifycharts.com/regional/us/daily/2019-09-25
# Link to top 200 songs on 2019-09-26: https://spotifycharts.com/regional/us/daily/2019-09-26
# Link to top 200 songs on 2019-09-27: https://spotifycharts.com/regional/us/daily/2019-09-27
# Link to top 200 songs on 2019-09-28: https://spotifycharts.com/regional/us/daily/2019-09-28
# Link to top 200 songs on 2019-09-29: https://spotifycharts.com/regional/us/daily/2019-09-29
# Link to top 200 songs on 2019-09-30: https://spotifycharts.com/regional/us/daily/2019-09-30
# Link to top 200 songs on 2019-10-01: https://spotifycharts.com/regional/us/daily/2019-10-01
# Link to top 200 songs on 2019-10-02: https://spotifycharts.com/regional/us/daily/2019-10-02
# Link to top 200 songs on 2019-10-03: https://spotifycharts.com/regional/us/daily/2019-10-03
# Link to top 200 songs on 2019-10-04: https://spotifycharts.com/regional/us/daily/2019-10-04
# Link to top 200 songs on 2019-10-05: https://spotifycharts.com/regional/us/daily/2019-10-05
# Link to top 200 songs on 2019-10-06: https://spotifycharts.com/regional/us/daily/2019-10-06
# Link to top 200 songs on 2019-10-07: https://spotifycharts.com/regional/us/daily/2019-10-07
# Link to top 200 songs on 2019-10-08: https://spotifycharts.com/regional/us/daily/2019-10-08
# Link to top 200 songs on 2019-10-09: https://spotifycharts.com/regional/us/daily/2019-10-09
# Link to top 200 songs on 2019-10-10: https://spotifycharts.com/regional/us/daily/2019-10-10
# Link to top 200 songs on 2019-10-11: https://spotifycharts.com/regional/us/daily/2019-10-11
# Link to top 200 songs on 2019-10-12: https://spotifycharts.com/regional/us/daily/2019-10-12
# Link to top 200 songs on 2019-10-13: https://spotifycharts.com/regional/us/daily/2019-10-13
# Link to top 200 songs on 2019-10-14: https://spotifycharts.com/regional/us/daily/2019-10-14
# Link to top 200 songs on 2019-10-15: https://spotifycharts.com/regional/us/daily/2019-10-15
# Link to top 200 songs on 2019-10-16: https://spotifycharts.com/regional/us/daily/2019-10-16
# Link to top 200 songs on 2019-10-17: https://spotifycharts.com/regional/us/daily/2019-10-17
# Link to top 200 songs on 2019-10-18: https://spotifycharts.com/regional/us/daily/2019-10-18
# Link to top 200 songs on 2019-10-19: https://spotifycharts.com/regional/us/daily/2019-10-19
# Link to top 200 songs on 2019-10-20: https://spotifycharts.com/regional/us/daily/2019-10-20
# Link to top 200 songs on 2019-10-21: https://spotifycharts.com/regional/us/daily/2019-10-21
# Link to top 200 songs on 2019-10-22: https://spotifycharts.com/regional/us/daily/2019-10-22
# Link to top 200 songs on 2019-10-23: https://spotifycharts.com/regional/us/daily/2019-10-23
# Link to top 200 songs on 2019-10-24: https://spotifycharts.com/regional/us/daily/2019-10-24
# Link to top 200 songs on 2019-10-25: https://spotifycharts.com/regional/us/daily/2019-10-25
# Link to top 200 songs on 2019-10-26: https://spotifycharts.com/regional/us/daily/2019-10-26
# Link to top 200 songs on 2019-10-27: https://spotifycharts.com/regional/us/daily/2019-10-27
# Link to top 200 songs on 2019-10-28: https://spotifycharts.com/regional/us/daily/2019-10-28
# Link to top 200 songs on 2019-10-29: https://spotifycharts.com/regional/us/daily/2019-10-29
# Link to top 200 songs on 2019-10-30: https://spotifycharts.com/regional/us/daily/2019-10-30
# Link to top 200 songs on 2019-10-31: https://spotifycharts.com/regional/us/daily/2019-10-31
# Link to top 200 songs on 2019-11-01: https://spotifycharts.com/regional/us/daily/2019-11-01
# Link to top 200 songs on 2019-11-02: https://spotifycharts.com/regional/us/daily/2019-11-02
# Link to top 200 songs on 2019-11-03: https://spotifycharts.com/regional/us/daily/2019-11-03
# Link to top 200 songs on 2019-11-04: https://spotifycharts.com/regional/us/daily/2019-11-04
# Link to top 200 songs on 2019-11-05: https://spotifycharts.com/regional/us/daily/2019-11-05
# Link to top 200 songs on 2019-11-06: https://spotifycharts.com/regional/us/daily/2019-11-06
# Link to top 200 songs on 2019-11-07: https://spotifycharts.com/regional/us/daily/2019-11-07
# Link to top 200 songs on 2019-11-08: https://spotifycharts.com/regional/us/daily/2019-11-08
# Link to top 200 songs on 2019-11-09: https://spotifycharts.com/regional/us/daily/2019-11-09
# Link to top 200 songs on 2019-11-10: https://spotifycharts.com/regional/us/daily/2019-11-10
# Link to top 200 songs on 2019-11-11: https://spotifycharts.com/regional/us/daily/2019-11-11
# Link to top 200 songs on 2019-11-12: https://spotifycharts.com/regional/us/daily/2019-11-12
# Link to top 200 songs on 2019-11-13: https://spotifycharts.com/regional/us/daily/2019-11-13
# Link to top 200 songs on 2019-11-14: https://spotifycharts.com/regional/us/daily/2019-11-14
# Link to top 200 songs on 2019-11-15: https://spotifycharts.com/regional/us/daily/2019-11-15
# Link to top 200 songs on 2019-11-16: https://spotifycharts.com/regional/us/daily/2019-11-16
# Link to top 200 songs on 2019-11-17: https://spotifycharts.com/regional/us/daily/2019-11-17
# Link to top 200 songs on 2019-11-18: https://spotifycharts.com/regional/us/daily/2019-11-18
# Link to top 200 songs on 2019-11-19: https://spotifycharts.com/regional/us/daily/2019-11-19
# Link to top 200 songs on 2019-11-20: https://spotifycharts.com/regional/us/daily/2019-11-20
# Link to top 200 songs on 2019-11-21: https://spotifycharts.com/regional/us/daily/2019-11-21
# Link to top 200 songs on 2019-11-22: https://spotifycharts.com/regional/us/daily/2019-11-22
# Link to top 200 songs on 2019-11-23: https://spotifycharts.com/regional/us/daily/2019-11-23
# Link to top 200 songs on 2019-11-24: https://spotifycharts.com/regional/us/daily/2019-11-24
# Link to top 200 songs on 2019-11-25: https://spotifycharts.com/regional/us/daily/2019-11-25
# Link to top 200 songs on 2019-11-26: https://spotifycharts.com/regional/us/daily/2019-11-26
# Link to top 200 songs on 2019-11-27: https://spotifycharts.com/regional/us/daily/2019-11-27
# Link to top 200 songs on 2019-11-28: https://spotifycharts.com/regional/us/daily/2019-11-28
# Link to top 200 songs on 2019-11-29: https://spotifycharts.com/regional/us/daily/2019-11-29
# Link to top 200 songs on 2019-11-30: https://spotifycharts.com/regional/us/daily/2019-11-30
# Link to top 200 songs on 2019-12-01: https://spotifycharts.com/regional/us/daily/2019-12-01
# Link to top 200 songs on 2019-12-02: https://spotifycharts.com/regional/us/daily/2019-12-02
# Link to top 200 songs on 2019-12-03: https://spotifycharts.com/regional/us/daily/2019-12-03
# Link to top 200 songs on 2019-12-04: https://spotifycharts.com/regional/us/daily/2019-12-04
# Link to top 200 songs on 2019-12-05: https://spotifycharts.com/regional/us/daily/2019-12-05
# Link to top 200 songs on 2019-12-06: https://spotifycharts.com/regional/us/daily/2019-12-06
# Link to top 200 songs on 2019-12-07: https://spotifycharts.com/regional/us/daily/2019-12-07
# Link to top 200 songs on 2019-12-08: https://spotifycharts.com/regional/us/daily/2019-12-08
# Link to top 200 songs on 2019-12-09: https://spotifycharts.com/regional/us/daily/2019-12-09
# Link to top 200 songs on 2019-12-10: https://spotifycharts.com/regional/us/daily/2019-12-10
# Link to top 200 songs on 2019-12-11: https://spotifycharts.com/regional/us/daily/2019-12-11
# Link to top 200 songs on 2019-12-12: https://spotifycharts.com/regional/us/daily/2019-12-12
# Link to top 200 songs on 2019-12-13: https://spotifycharts.com/regional/us/daily/2019-12-13
# Link to top 200 songs on 2019-12-14: https://spotifycharts.com/regional/us/daily/2019-12-14
# Link to top 200 songs on 2019-12-15: https://spotifycharts.com/regional/us/daily/2019-12-15
# Link to top 200 songs on 2019-12-16: https://spotifycharts.com/regional/us/daily/2019-12-16
# Link to top 200 songs on 2019-12-17: https://spotifycharts.com/regional/us/daily/2019-12-17
# Link to top 200 songs on 2019-12-18: https://spotifycharts.com/regional/us/daily/2019-12-18
# Link to top 200 songs on 2019-12-19: https://spotifycharts.com/regional/us/daily/2019-12-19
# Link to top 200 songs on 2019-12-20: https://spotifycharts.com/regional/us/daily/2019-12-20
# Link to top 200 songs on 2019-12-21: https://spotifycharts.com/regional/us/daily/2019-12-21
# Link to top 200 songs on 2019-12-22: https://spotifycharts.com/regional/us/daily/2019-12-22
# Link to top 200 songs on 2019-12-23: https://spotifycharts.com/regional/us/daily/2019-12-23
# Link to top 200 songs on 2019-12-24: https://spotifycharts.com/regional/us/daily/2019-12-24
# Link to top 200 songs on 2019-12-25: https://spotifycharts.com/regional/us/daily/2019-12-25
# Link to top 200 songs on 2019-12-26: https://spotifycharts.com/regional/us/daily/2019-12-26
# Link to top 200 songs on 2019-12-27: https://spotifycharts.com/regional/us/daily/2019-12-27
# Link to top 200 songs on 2019-12-28: https://spotifycharts.com/regional/us/daily/2019-12-28
# Link to top 200 songs on 2019-12-29: https://spotifycharts.com/regional/us/daily/2019-12-29
# Link to top 200 songs on 2019-12-30: https://spotifycharts.com/regional/us/daily/2019-12-30

# %% [markdown]
# Next, we define `get_table(link)` and `track_artist`. These functions read the html of the Spotify Charts website and then add the relevant data to a dataframe.

# %% [markdown]
# `get_table(link)` uses the pandas function `read_html()` and Beautiful Soup to return a dataframe of the top 50 songs for whatever Spotify Charts page that the function has been called on. The dataframe that `get_table(link)` returns includes the song's `position` (where it was ranked that day), `track` (the name of the track and who the track's artist), `streams` (the number of times the song has been streamed), `date` (the date that the user is looking at), and `url` (the link to the song on Spotify).
#
# As you can see, we use a package called `cloudscraper` instead of `requests` in order to get and read the information that the link contains. We intiially were using the `requests` package to perform our webscraping, however, Spotify installed CloudFlare DDOS protection on their website mid-project which required us to switch the packages we used.

# %%
def get_table(link):
    '''
    a function that returns a table of the top 50 songs from a spotify chart
    with the following columns:
    track. a string, "[track name] by [artist]"
    position. an int, the ranking of the track on the chart.
    streams. an int, # of streams of the track on a specified date.
    date. a date time obj. the day the song was streamed.
    url. a url to the song on Spotify.
    
    argument: a string, which is a link to a Spotify chart. eg. 'https://spotifycharts.com/regional/us/daily/2020-01-01'
    '''
    #getting the df
    scraper = cloudscraper.create_scraper()
    r = scraper.get(link)
    df_list = pd.read_html(r.text) # this parses all the tables in webpages to a lis
    df = df_list[0]
    #for the purposes of our project, we only want the top 50 songs of the table that was scraped from the
    #spotify website, which gives us top 200. we find that 200 songs per day was excessive
    df=df.head(50)

    #cleaning column names and dropping irrelevant columns
    #to lowercase
    cols= [x.lower() for x in df.columns] 
    df.columns=cols
    #after scraping, Spotify returns a column 'unnamed: 1', which is actually the position of the song on the chart.
    #which we have renamed
    df = df.rename(columns={'unnamed: 1': 'position'})
    #it also returns two NaN columns, which we drop here
    df=df.drop(columns=["unnamed: 0","unnamed: 2"])
    
    #adding a date column by parsing the link used in the argument.
    df["date"]=link[-10:]
    df['date']=pd.to_datetime(df['date'])
    
    #creating the url column
    #using Beautiful soup to webscrape the links on the site.
    datasoup = bs4.BeautifulSoup(r.text, 'html.parser')
    aList=[]
    #find all 'a' tags
    for data in datasoup.findAll('a'):
        aList.append(data)
    links=[]
    #find all href tags
    for x in aList:
        links.append(x.get('href'))
    #drop None types
    clean = filter(None, links)
    urls=[]
    #only keep the links that are links to spotify tracks.
    for x in clean:
        if 'open.spotify.com/track/' in x:
            urls.append(x)
    #only append the top 50 to the dataframe
    df['url']=urls[:50]
    return df

# %% [markdown]
# Before using `cloudscraper`, when we ran `get_table(link)` we received the error message:

# %%
test=get_table('https://spotifycharts.com/regional/us/daily/2021-05-09')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-b8d6b4ba7ba5> in <module>
# ----> 1 test=get_table('https://spotifycharts.com/regional/us/daily/2021-05-09')
#
# <ipython-input-19-250097d08986> in get_table(link)
#      14     scraper = cloudscraper.create_scraper()
#      15     r = requests.get(link)
# ---> 16     df_list = pd.read_html(r.text) # this parses all the tables in webpages to a lis
#      17     df = df_list[0]
#      18     #for the purposes of our project, we only want the top 50 songs of the table that was scraped from the
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1099         na_values=na_values,
#    1100         keep_default_na=keep_default_na,
# -> 1101         displayed_only=displayed_only,
#    1102     )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     915             break
#     916     else:
# --> 917         raise retained
#     918
#     919     ret = []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     896
#     897         try:
# --> 898             tables = p.parse_tables()
#     899         except ValueError as caught:
#     900             # if `io` is an io-like object, check if it's seekable
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in parse_tables(self)
#     215         list of parsed (header, body, footer) tuples from tables.
#     216         """
# --> 217         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     218         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     219
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse_tables(self, doc, match, attrs)
#     545
#     546         if not tables:
# --> 547             raise ValueError("No tables found")
#     548
#     549         result = []
#
# ValueError: No tables found

# %% [markdown]
# Once using `cloudscraper`, this is the dataframe that `get_table(link)` returns when we call it on the link to the top 200 songs in the United States on May 5th, 2021:

# %%
get_table('https://spotifycharts.com/regional/us/daily/2021-05-09')
# Out:
#     position                                              track  streams  \
# 0          1              Kiss Me More (feat. SZA)  by Doja Cat  1490138
# 1          2                                 RAPSTAR  by Polo G  1369211
# 2          3  Miss The Rage (feat. Playboi Carti)  by Trippi...  1159962
# 3          4                      i n t e r l u d e  by J. Cole  1090993
# 4          5       MONTERO (Call Me By Your Name)  by Lil Nas X  1077197
# 5          6             Levitating (feat. DaBaby)  by Dua Lipa  1016614
# 6          7  Peaches (feat. Daniel Caesar & Giveon)  by Jus...   997462
# 7          8                         deja vu  by Olivia Rodrigo   823109
# 8          9             Astronaut In The Ocean  by Masked Wolf   742175
# 9         10  Leave The Door Open  by Bruno Mars, Anderson ....   698458
# 10        11                       Your Power  by Billie Eilish   657732
# 11        12                  Heartbreak Anniversary  by Giveon   644337
# 12        13                       Heat Waves  by Glass Animals   643319
# 13        14         Wants and Needs (feat. Lil Baby)  by Drake   617916
# 14        15                                     Up  by Cardi B   602867
# 15        16  Save Your Tears (with Ariana Grande) (Remix)  ...   578752
# 16        17                 drivers license  by Olivia Rodrigo   556581
# 17        18               Calling My Phone  by Lil Tjay, 6LACK   550498
# 18        19                           telepatía  by Kali Uchis   549668
# 19        20                               Streets  by Doja Cat   543748
# 20        21                                  Good Days  by SZA   525506
# 21        22                           Never Left  by Lil Tecca   518686
# 22        23          Best Friend (feat. Doja Cat)  by Saweetie   509015
# 23        24  Solid (feat. Drake)  by Young Stoner Life, You...   481783
# 24        25                     Blinding Lights  by The Weeknd   477879
# 25        26                  DÁKITI  by Bad Bunny, Jhay Cortez   462888
# 26        27    Back In Blood (feat. Lil Durk)  by Pooh Shiesty   458491
# 27        28  EVERY CHANCE I GET (feat. Lil Baby & Lil Durk)...   438534
# 28        29                           Martin & Gina  by Polo G   427464
# 29        30                Mood (feat. iann dior)  by 24kGoldn   421795
# 30        31  Beautiful Mistakes (feat. Megan Thee Stallion)...   407522
# 31        32  my ex's best friend (with blackbear)  by Machi...   398970
# 32        33  Headshot (feat. Polo G & Fivio Foreign)  by Li...   397682
# 33        34                              What’s Next  by Drake   394462
# 34        35              Sweater Weather  by The Neighbourhood   388367
# 35        36                          Hold On  by Justin Bieber   383847
# 36        37   WITHOUT YOU (with Miley Cyrus)  by The Kid LAROI   371794
# 37        38              Ramen & OJ  by Joyner Lucas, Lil Baby   371388
# 38        39                   Forever After All  by Luke Combs   371220
# 39        40                     Save Your Tears  by The Weeknd   370104
# 40        41                      What You Need  by Don Toliver   363782
# 41        42          Goosebumps - Remix  by Travis Scott, HVME   363271
# 42        43                        Big Gangsta  by Kevin Gates   355953
# 43        44                                 Runaway  by AURORA   353365
# 44        45  Lemonade (feat. Gunna, Don Toliver & NAV)  by ...   350262
# 45        46            ROCKSTAR (feat. Roddy Ricch)  by DaBaby   347369
# 46        47  Run It Up (feat. Offset & Moneybagg Yo)  by Li...   344952
# 47        48           Dreams - 2004 Remaster  by Fleetwood Mac   344144
# 48        49                                   Tampa  by Cico P   338572
# 49        50                 Dick (feat. Doja Cat)  by StarBoi3   335466
#
#          date                                                url
# 0  2021-05-09  https://open.spotify.com/track/748mdHapucXQri7...
# 1  2021-05-09  https://open.spotify.com/track/43PGPuHIlVOc04j...
# 2  2021-05-09  https://open.spotify.com/track/2BITQ360Knh6qNA...
# 3  2021-05-09  https://open.spotify.com/track/2gyYjQWXKxemhAy...
# 4  2021-05-09  https://open.spotify.com/track/67BtfxlNbhBmCDR...
# 5  2021-05-09  https://open.spotify.com/track/5nujrmhLynf4yMo...
# 6  2021-05-09  https://open.spotify.com/track/4iJyoBOLtHqaGxP...
# 7  2021-05-09  https://open.spotify.com/track/61KpQadow081I2A...
# 8  2021-05-09  https://open.spotify.com/track/3VT8hOC5vuDXBsH...
# 9  2021-05-09  https://open.spotify.com/track/7MAibcTli4IisCt...
# 10 2021-05-09  https://open.spotify.com/track/5qNh5WtzMbfpSj2...
# 11 2021-05-09  https://open.spotify.com/track/3FAJ6O0NOHQV8Mc...
# 12 2021-05-09  https://open.spotify.com/track/02MWAaffLxlfxAU...
# 13 2021-05-09  https://open.spotify.com/track/65OVbaJR5O1RmwO...
# 14 2021-05-09  https://open.spotify.com/track/1M4OcYkxAtu3Erz...
# 15 2021-05-09  https://open.spotify.com/track/37BZB0z9T8Xu7U3...
# 16 2021-05-09  https://open.spotify.com/track/7lPN2DXiMsVn7XU...
# 17 2021-05-09  https://open.spotify.com/track/3J8EOeKLTLXORtW...
# 18 2021-05-09  https://open.spotify.com/track/6tDDoYIxWvMLTdK...
# 19 2021-05-09  https://open.spotify.com/track/60ynsPSSKe6O3sf...
# 20 2021-05-09  https://open.spotify.com/track/3YJJjQPAbDT7mGp...
# 21 2021-05-09  https://open.spotify.com/track/21UkXrc9kD48rNp...
# 22 2021-05-09  https://open.spotify.com/track/20BOju91NaEFK5P...
# 23 2021-05-09  https://open.spotify.com/track/6rTInqW3YECMkQs...
# 24 2021-05-09  https://open.spotify.com/track/0VjIjW4GlUZAMYd...
# 25 2021-05-09  https://open.spotify.com/track/4MzXwWMhyBbmu6h...
# 26 2021-05-09  https://open.spotify.com/track/7FGdjbZ32vMybPu...
# 27 2021-05-09  https://open.spotify.com/track/1EJIcDYXwSqipW5...
# 28 2021-05-09  https://open.spotify.com/track/1VLtjHwRWOVJiE5...
# 29 2021-05-09  https://open.spotify.com/track/4jPy3l0RUwlUI9T...
# 30 2021-05-09  https://open.spotify.com/track/6fRxMU4LWwyaSSo...
# 31 2021-05-09  https://open.spotify.com/track/7kDUspsoYfLkWnZ...
# 32 2021-05-09  https://open.spotify.com/track/4eNOLmx8r2IJAVK...
# 33 2021-05-09  https://open.spotify.com/track/3aQem4jVGdhtg11...
# 34 2021-05-09  https://open.spotify.com/track/2QjOHCTQ1Jl3zaw...
# 35 2021-05-09  https://open.spotify.com/track/1nahzW3kfMuwReT...
# 36 2021-05-09  https://open.spotify.com/track/1EHUQesfVKwbtht...
# 37 2021-05-09  https://open.spotify.com/track/4TIqzdAssasqx3D...
# 38 2021-05-09  https://open.spotify.com/track/6IBcOGPsniK3Pso...
# 39 2021-05-09  https://open.spotify.com/track/5QO79kh1waicV47...
# 40 2021-05-09  https://open.spotify.com/track/6LcX2hBbXaJcK4A...
# 41 2021-05-09  https://open.spotify.com/track/5uEYRdEIh9Bo4fp...
# 42 2021-05-09  https://open.spotify.com/track/03ERnTvSV5fy8WA...
# 43 2021-05-09  https://open.spotify.com/track/1v1oIWf2Xgh54kI...
# 44 2021-05-09  https://open.spotify.com/track/7hxHWCCAIIxFLCz...
# 45 2021-05-09  https://open.spotify.com/track/7ytR5pFWmSjzHJI...
# 46 2021-05-09  https://open.spotify.com/track/1dg3qy5DjoJodaw...
# 47 2021-05-09  https://open.spotify.com/track/0ofHAoxe9vBkTCp...
# 48 2021-05-09  https://open.spotify.com/track/5jc4Qcs98R4ZDku...
# 49 2021-05-09  https://open.spotify.com/track/3nY8AqaMNNHHLYV...

# %% [markdown]
# As you can see in the dataframe above, `get_table(link)` puts a track name and the track's artist in the same column. We want track name and track artist to be in two separate columns. This is what `track_artist(df)` does.

# %%
def track_artist(df):
    '''
    returns a df that takes "track" column, which contains both the artist and song. 
    it is a string formatted as "[track name] by [artist]"
    and parses it into 2 columns: track_name and artist.
    and deletes the track column after.
    
    argument: a dataframe created by get_table(), containing a column "track"
    with each observation a string formatted as "[track name] by [artist]"
    '''
    tracks=df.track.values
    songtitles=[]
    songartists=[]
    for song in tracks:
        index1=song.find("  by")
        index2=song.find("by ")
        track=song[:index1]
        songtitles.append(track)
        artist=song[index2+3:]
        songartists.append(artist)
    df["track_name"]=songtitles
    df["artist"]=songartists
    df=df.drop(columns=["track"])
    return df

# %% [markdown]
# Once we defined all of our functions, it was time to actually call the functions on each country. Instead of using a for-loop to call `get_table(link)` and `track_artist(df)` on all of the countries in `happy2019` and `happy2020`, we manually ran all of these functions on the 40 countries. We did this in order to run our functions on multiple countries at once, using different kernels. We also print the links since sometimes the webscraper would crash at a random date. Printing the links would let us see where the webscraper stopped, and then modify our the dates for which we were webscraping.
#
# Shown below is an example of how we ran our function on Norway. We did this for every country, replacing "Norway" with the country name and "no" with the 2-letter abbreviation for the country.

# %%
norway=create_links_2019("no")
norway2019=pd.DataFrame()

# %%
for link in norway:
    df=get_table(link)
    df=track_artist(df)
    df['region']="no"
    norway2019=norway2019.append(df,ignore_index=True)
    print(link)
norway2019['region']='Norway'
norway2019
# Out:
# https://spotifycharts.com/regional/no/daily/2019-01-01
# https://spotifycharts.com/regional/no/daily/2019-01-02
# https://spotifycharts.com/regional/no/daily/2019-01-03
# https://spotifycharts.com/regional/no/daily/2019-01-04
# https://spotifycharts.com/regional/no/daily/2019-01-05
# https://spotifycharts.com/regional/no/daily/2019-01-06
# https://spotifycharts.com/regional/no/daily/2019-01-07
# https://spotifycharts.com/regional/no/daily/2019-01-08
# https://spotifycharts.com/regional/no/daily/2019-01-09
# https://spotifycharts.com/regional/no/daily/2019-01-10
# https://spotifycharts.com/regional/no/daily/2019-01-11
# https://spotifycharts.com/regional/no/daily/2019-01-12
# https://spotifycharts.com/regional/no/daily/2019-01-13
# https://spotifycharts.com/regional/no/daily/2019-01-14
# https://spotifycharts.com/regional/no/daily/2019-01-15
# https://spotifycharts.com/regional/no/daily/2019-01-16
# https://spotifycharts.com/regional/no/daily/2019-01-17
# https://spotifycharts.com/regional/no/daily/2019-01-18
# https://spotifycharts.com/regional/no/daily/2019-01-19
# https://spotifycharts.com/regional/no/daily/2019-01-20
# https://spotifycharts.com/regional/no/daily/2019-01-21
# https://spotifycharts.com/regional/no/daily/2019-01-22
# https://spotifycharts.com/regional/no/daily/2019-01-23
# https://spotifycharts.com/regional/no/daily/2019-01-24
# https://spotifycharts.com/regional/no/daily/2019-01-25
# https://spotifycharts.com/regional/no/daily/2019-01-26
# https://spotifycharts.com/regional/no/daily/2019-01-27
# https://spotifycharts.com/regional/no/daily/2019-01-28
# https://spotifycharts.com/regional/no/daily/2019-01-29
# https://spotifycharts.com/regional/no/daily/2019-01-30
# https://spotifycharts.com/regional/no/daily/2019-01-31
# https://spotifycharts.com/regional/no/daily/2019-02-01
# https://spotifycharts.com/regional/no/daily/2019-02-02
# https://spotifycharts.com/regional/no/daily/2019-02-03
# https://spotifycharts.com/regional/no/daily/2019-02-04
# https://spotifycharts.com/regional/no/daily/2019-02-05
# https://spotifycharts.com/regional/no/daily/2019-02-06
# https://spotifycharts.com/regional/no/daily/2019-02-07
# https://spotifycharts.com/regional/no/daily/2019-02-08
# https://spotifycharts.com/regional/no/daily/2019-02-09
# https://spotifycharts.com/regional/no/daily/2019-02-10
# https://spotifycharts.com/regional/no/daily/2019-02-11
# https://spotifycharts.com/regional/no/daily/2019-02-12
# https://spotifycharts.com/regional/no/daily/2019-02-13
# https://spotifycharts.com/regional/no/daily/2019-02-14
# https://spotifycharts.com/regional/no/daily/2019-02-15
# https://spotifycharts.com/regional/no/daily/2019-02-16
# https://spotifycharts.com/regional/no/daily/2019-02-17
# https://spotifycharts.com/regional/no/daily/2019-02-18
# https://spotifycharts.com/regional/no/daily/2019-02-19
# https://spotifycharts.com/regional/no/daily/2019-02-20
# https://spotifycharts.com/regional/no/daily/2019-02-21
# https://spotifycharts.com/regional/no/daily/2019-02-22
# https://spotifycharts.com/regional/no/daily/2019-02-23
# https://spotifycharts.com/regional/no/daily/2019-02-24
# https://spotifycharts.com/regional/no/daily/2019-02-25
# https://spotifycharts.com/regional/no/daily/2019-02-26
# https://spotifycharts.com/regional/no/daily/2019-02-27
# https://spotifycharts.com/regional/no/daily/2019-02-28
# https://spotifycharts.com/regional/no/daily/2019-03-01
# https://spotifycharts.com/regional/no/daily/2019-03-02
# https://spotifycharts.com/regional/no/daily/2019-03-03
# https://spotifycharts.com/regional/no/daily/2019-03-04
# https://spotifycharts.com/regional/no/daily/2019-03-05
# https://spotifycharts.com/regional/no/daily/2019-03-06
# https://spotifycharts.com/regional/no/daily/2019-03-07
# https://spotifycharts.com/regional/no/daily/2019-03-08
# https://spotifycharts.com/regional/no/daily/2019-03-09
# https://spotifycharts.com/regional/no/daily/2019-03-10
# https://spotifycharts.com/regional/no/daily/2019-03-11
# https://spotifycharts.com/regional/no/daily/2019-03-12
# https://spotifycharts.com/regional/no/daily/2019-03-13
# https://spotifycharts.com/regional/no/daily/2019-03-14
# https://spotifycharts.com/regional/no/daily/2019-03-15
# https://spotifycharts.com/regional/no/daily/2019-03-16
# https://spotifycharts.com/regional/no/daily/2019-03-17
# https://spotifycharts.com/regional/no/daily/2019-03-18
# https://spotifycharts.com/regional/no/daily/2019-03-19
# https://spotifycharts.com/regional/no/daily/2019-03-20
# https://spotifycharts.com/regional/no/daily/2019-03-21
# https://spotifycharts.com/regional/no/daily/2019-03-22
# https://spotifycharts.com/regional/no/daily/2019-03-23
# https://spotifycharts.com/regional/no/daily/2019-03-24
# https://spotifycharts.com/regional/no/daily/2019-03-25
# https://spotifycharts.com/regional/no/daily/2019-03-26
# https://spotifycharts.com/regional/no/daily/2019-03-27
# https://spotifycharts.com/regional/no/daily/2019-03-28
# https://spotifycharts.com/regional/no/daily/2019-03-29
# https://spotifycharts.com/regional/no/daily/2019-03-30
# https://spotifycharts.com/regional/no/daily/2019-03-31
# https://spotifycharts.com/regional/no/daily/2019-04-01
# https://spotifycharts.com/regional/no/daily/2019-04-02
# https://spotifycharts.com/regional/no/daily/2019-04-03
# https://spotifycharts.com/regional/no/daily/2019-04-04
# https://spotifycharts.com/regional/no/daily/2019-04-05
# https://spotifycharts.com/regional/no/daily/2019-04-06
# https://spotifycharts.com/regional/no/daily/2019-04-07
# https://spotifycharts.com/regional/no/daily/2019-04-08
# https://spotifycharts.com/regional/no/daily/2019-04-09
# https://spotifycharts.com/regional/no/daily/2019-04-10
# https://spotifycharts.com/regional/no/daily/2019-04-11
# https://spotifycharts.com/regional/no/daily/2019-04-12
# https://spotifycharts.com/regional/no/daily/2019-04-13
# https://spotifycharts.com/regional/no/daily/2019-04-14
# https://spotifycharts.com/regional/no/daily/2019-04-15
# https://spotifycharts.com/regional/no/daily/2019-04-16
# https://spotifycharts.com/regional/no/daily/2019-04-17
# https://spotifycharts.com/regional/no/daily/2019-04-18
# https://spotifycharts.com/regional/no/daily/2019-04-19
# https://spotifycharts.com/regional/no/daily/2019-04-20
# https://spotifycharts.com/regional/no/daily/2019-04-21
# https://spotifycharts.com/regional/no/daily/2019-04-22
# https://spotifycharts.com/regional/no/daily/2019-04-23
# https://spotifycharts.com/regional/no/daily/2019-04-24
# https://spotifycharts.com/regional/no/daily/2019-04-25
# https://spotifycharts.com/regional/no/daily/2019-04-26
# https://spotifycharts.com/regional/no/daily/2019-04-27
# https://spotifycharts.com/regional/no/daily/2019-04-28
# https://spotifycharts.com/regional/no/daily/2019-04-29
# https://spotifycharts.com/regional/no/daily/2019-04-30
# https://spotifycharts.com/regional/no/daily/2019-05-01
# https://spotifycharts.com/regional/no/daily/2019-05-02
# https://spotifycharts.com/regional/no/daily/2019-05-03
# https://spotifycharts.com/regional/no/daily/2019-05-04
# https://spotifycharts.com/regional/no/daily/2019-05-05
# https://spotifycharts.com/regional/no/daily/2019-05-06
# https://spotifycharts.com/regional/no/daily/2019-05-07
# https://spotifycharts.com/regional/no/daily/2019-05-08
# https://spotifycharts.com/regional/no/daily/2019-05-09
# https://spotifycharts.com/regional/no/daily/2019-05-10
# https://spotifycharts.com/regional/no/daily/2019-05-11
# https://spotifycharts.com/regional/no/daily/2019-05-12
# https://spotifycharts.com/regional/no/daily/2019-05-13
# https://spotifycharts.com/regional/no/daily/2019-05-14
# https://spotifycharts.com/regional/no/daily/2019-05-15
# https://spotifycharts.com/regional/no/daily/2019-05-16
# https://spotifycharts.com/regional/no/daily/2019-05-17
# https://spotifycharts.com/regional/no/daily/2019-05-18
# https://spotifycharts.com/regional/no/daily/2019-05-19
# https://spotifycharts.com/regional/no/daily/2019-05-20
# https://spotifycharts.com/regional/no/daily/2019-05-21
# https://spotifycharts.com/regional/no/daily/2019-05-22
# https://spotifycharts.com/regional/no/daily/2019-05-23
# https://spotifycharts.com/regional/no/daily/2019-05-24
# https://spotifycharts.com/regional/no/daily/2019-05-25
# https://spotifycharts.com/regional/no/daily/2019-05-26
# https://spotifycharts.com/regional/no/daily/2019-05-27
# https://spotifycharts.com/regional/no/daily/2019-05-28
# https://spotifycharts.com/regional/no/daily/2019-05-29
# https://spotifycharts.com/regional/no/daily/2019-05-30
# https://spotifycharts.com/regional/no/daily/2019-05-31
# https://spotifycharts.com/regional/no/daily/2019-06-01
# https://spotifycharts.com/regional/no/daily/2019-06-02
# https://spotifycharts.com/regional/no/daily/2019-06-03
# https://spotifycharts.com/regional/no/daily/2019-06-04
# https://spotifycharts.com/regional/no/daily/2019-06-05
# https://spotifycharts.com/regional/no/daily/2019-06-06
# https://spotifycharts.com/regional/no/daily/2019-06-07
# https://spotifycharts.com/regional/no/daily/2019-06-08
# https://spotifycharts.com/regional/no/daily/2019-06-09
# https://spotifycharts.com/regional/no/daily/2019-06-10
# https://spotifycharts.com/regional/no/daily/2019-06-11
# https://spotifycharts.com/regional/no/daily/2019-06-12
# https://spotifycharts.com/regional/no/daily/2019-06-13
# https://spotifycharts.com/regional/no/daily/2019-06-14
# https://spotifycharts.com/regional/no/daily/2019-06-15
# https://spotifycharts.com/regional/no/daily/2019-06-16
# https://spotifycharts.com/regional/no/daily/2019-06-17
# https://spotifycharts.com/regional/no/daily/2019-06-18
# https://spotifycharts.com/regional/no/daily/2019-06-19
# https://spotifycharts.com/regional/no/daily/2019-06-20
# https://spotifycharts.com/regional/no/daily/2019-06-21
# https://spotifycharts.com/regional/no/daily/2019-06-22
# https://spotifycharts.com/regional/no/daily/2019-06-23
# https://spotifycharts.com/regional/no/daily/2019-06-24
# https://spotifycharts.com/regional/no/daily/2019-06-25
# https://spotifycharts.com/regional/no/daily/2019-06-26
# https://spotifycharts.com/regional/no/daily/2019-06-27
# https://spotifycharts.com/regional/no/daily/2019-06-28
# https://spotifycharts.com/regional/no/daily/2019-06-29
# https://spotifycharts.com/regional/no/daily/2019-06-30
# https://spotifycharts.com/regional/no/daily/2019-07-01
# https://spotifycharts.com/regional/no/daily/2019-07-02
# https://spotifycharts.com/regional/no/daily/2019-07-03
# https://spotifycharts.com/regional/no/daily/2019-07-04
# https://spotifycharts.com/regional/no/daily/2019-07-05
# https://spotifycharts.com/regional/no/daily/2019-07-06
# https://spotifycharts.com/regional/no/daily/2019-07-07
# https://spotifycharts.com/regional/no/daily/2019-07-08
# https://spotifycharts.com/regional/no/daily/2019-07-09
# https://spotifycharts.com/regional/no/daily/2019-07-10
# https://spotifycharts.com/regional/no/daily/2019-07-11
# https://spotifycharts.com/regional/no/daily/2019-07-12
# https://spotifycharts.com/regional/no/daily/2019-07-13
# https://spotifycharts.com/regional/no/daily/2019-07-14
# https://spotifycharts.com/regional/no/daily/2019-07-15
# https://spotifycharts.com/regional/no/daily/2019-07-16
# https://spotifycharts.com/regional/no/daily/2019-07-17
# https://spotifycharts.com/regional/no/daily/2019-07-18
# https://spotifycharts.com/regional/no/daily/2019-07-19
# https://spotifycharts.com/regional/no/daily/2019-07-20
# https://spotifycharts.com/regional/no/daily/2019-07-21
# https://spotifycharts.com/regional/no/daily/2019-07-22
# https://spotifycharts.com/regional/no/daily/2019-07-23
# https://spotifycharts.com/regional/no/daily/2019-07-24
# https://spotifycharts.com/regional/no/daily/2019-07-25
# https://spotifycharts.com/regional/no/daily/2019-07-26
# https://spotifycharts.com/regional/no/daily/2019-07-27
# https://spotifycharts.com/regional/no/daily/2019-07-28
# https://spotifycharts.com/regional/no/daily/2019-07-29
# https://spotifycharts.com/regional/no/daily/2019-07-30
# https://spotifycharts.com/regional/no/daily/2019-07-31
# https://spotifycharts.com/regional/no/daily/2019-08-01
# https://spotifycharts.com/regional/no/daily/2019-08-02
# https://spotifycharts.com/regional/no/daily/2019-08-03
# https://spotifycharts.com/regional/no/daily/2019-08-04
# https://spotifycharts.com/regional/no/daily/2019-08-05
# https://spotifycharts.com/regional/no/daily/2019-08-06
# https://spotifycharts.com/regional/no/daily/2019-08-07
# https://spotifycharts.com/regional/no/daily/2019-08-08
# https://spotifycharts.com/regional/no/daily/2019-08-09
# https://spotifycharts.com/regional/no/daily/2019-08-10
# https://spotifycharts.com/regional/no/daily/2019-08-11
# https://spotifycharts.com/regional/no/daily/2019-08-12
# https://spotifycharts.com/regional/no/daily/2019-08-13
# https://spotifycharts.com/regional/no/daily/2019-08-14
# https://spotifycharts.com/regional/no/daily/2019-08-15
# https://spotifycharts.com/regional/no/daily/2019-08-16
# https://spotifycharts.com/regional/no/daily/2019-08-17
# https://spotifycharts.com/regional/no/daily/2019-08-18
# https://spotifycharts.com/regional/no/daily/2019-08-19
# https://spotifycharts.com/regional/no/daily/2019-08-20
# https://spotifycharts.com/regional/no/daily/2019-08-21
# https://spotifycharts.com/regional/no/daily/2019-08-22
# https://spotifycharts.com/regional/no/daily/2019-08-23
# https://spotifycharts.com/regional/no/daily/2019-08-24
# https://spotifycharts.com/regional/no/daily/2019-08-25
# https://spotifycharts.com/regional/no/daily/2019-08-26
# https://spotifycharts.com/regional/no/daily/2019-08-27
# https://spotifycharts.com/regional/no/daily/2019-08-28
# https://spotifycharts.com/regional/no/daily/2019-08-29
# https://spotifycharts.com/regional/no/daily/2019-08-30
# https://spotifycharts.com/regional/no/daily/2019-08-31
# https://spotifycharts.com/regional/no/daily/2019-09-01
# https://spotifycharts.com/regional/no/daily/2019-09-02
# https://spotifycharts.com/regional/no/daily/2019-09-03
# https://spotifycharts.com/regional/no/daily/2019-09-04
# https://spotifycharts.com/regional/no/daily/2019-09-05
# https://spotifycharts.com/regional/no/daily/2019-09-06
# https://spotifycharts.com/regional/no/daily/2019-09-07
# https://spotifycharts.com/regional/no/daily/2019-09-08
# https://spotifycharts.com/regional/no/daily/2019-09-09
# https://spotifycharts.com/regional/no/daily/2019-09-10
# https://spotifycharts.com/regional/no/daily/2019-09-11
# https://spotifycharts.com/regional/no/daily/2019-09-12
# https://spotifycharts.com/regional/no/daily/2019-09-13
# https://spotifycharts.com/regional/no/daily/2019-09-14
# https://spotifycharts.com/regional/no/daily/2019-09-15
# https://spotifycharts.com/regional/no/daily/2019-09-16
# https://spotifycharts.com/regional/no/daily/2019-09-17
# https://spotifycharts.com/regional/no/daily/2019-09-18
# https://spotifycharts.com/regional/no/daily/2019-09-19
# https://spotifycharts.com/regional/no/daily/2019-09-20
# https://spotifycharts.com/regional/no/daily/2019-09-21
# https://spotifycharts.com/regional/no/daily/2019-09-22
# https://spotifycharts.com/regional/no/daily/2019-09-23
# https://spotifycharts.com/regional/no/daily/2019-09-24
# https://spotifycharts.com/regional/no/daily/2019-09-25
# https://spotifycharts.com/regional/no/daily/2019-09-26
# https://spotifycharts.com/regional/no/daily/2019-09-27
# https://spotifycharts.com/regional/no/daily/2019-09-28
# https://spotifycharts.com/regional/no/daily/2019-09-29
# https://spotifycharts.com/regional/no/daily/2019-09-30
# https://spotifycharts.com/regional/no/daily/2019-10-01
# https://spotifycharts.com/regional/no/daily/2019-10-02
# https://spotifycharts.com/regional/no/daily/2019-10-03
# https://spotifycharts.com/regional/no/daily/2019-10-04
# https://spotifycharts.com/regional/no/daily/2019-10-05
# https://spotifycharts.com/regional/no/daily/2019-10-06
# https://spotifycharts.com/regional/no/daily/2019-10-07
# https://spotifycharts.com/regional/no/daily/2019-10-08
# https://spotifycharts.com/regional/no/daily/2019-10-09
# https://spotifycharts.com/regional/no/daily/2019-10-10
# https://spotifycharts.com/regional/no/daily/2019-10-11
# https://spotifycharts.com/regional/no/daily/2019-10-12
# https://spotifycharts.com/regional/no/daily/2019-10-13
# https://spotifycharts.com/regional/no/daily/2019-10-14
# https://spotifycharts.com/regional/no/daily/2019-10-15
# https://spotifycharts.com/regional/no/daily/2019-10-16
# https://spotifycharts.com/regional/no/daily/2019-10-17
# https://spotifycharts.com/regional/no/daily/2019-10-18
# https://spotifycharts.com/regional/no/daily/2019-10-19
# https://spotifycharts.com/regional/no/daily/2019-10-20
# https://spotifycharts.com/regional/no/daily/2019-10-21
# https://spotifycharts.com/regional/no/daily/2019-10-22
# https://spotifycharts.com/regional/no/daily/2019-10-23
# https://spotifycharts.com/regional/no/daily/2019-10-24
# https://spotifycharts.com/regional/no/daily/2019-10-25
# https://spotifycharts.com/regional/no/daily/2019-10-26
# https://spotifycharts.com/regional/no/daily/2019-10-27
# https://spotifycharts.com/regional/no/daily/2019-10-28
# https://spotifycharts.com/regional/no/daily/2019-10-29
# https://spotifycharts.com/regional/no/daily/2019-10-30
# https://spotifycharts.com/regional/no/daily/2019-10-31
# https://spotifycharts.com/regional/no/daily/2019-11-01
# https://spotifycharts.com/regional/no/daily/2019-11-02
# https://spotifycharts.com/regional/no/daily/2019-11-03
# https://spotifycharts.com/regional/no/daily/2019-11-04
# https://spotifycharts.com/regional/no/daily/2019-11-05
# https://spotifycharts.com/regional/no/daily/2019-11-06
# https://spotifycharts.com/regional/no/daily/2019-11-07
# https://spotifycharts.com/regional/no/daily/2019-11-08
# https://spotifycharts.com/regional/no/daily/2019-11-09
# https://spotifycharts.com/regional/no/daily/2019-11-10
# https://spotifycharts.com/regional/no/daily/2019-11-11
# https://spotifycharts.com/regional/no/daily/2019-11-12
# https://spotifycharts.com/regional/no/daily/2019-11-13
# https://spotifycharts.com/regional/no/daily/2019-11-14
# https://spotifycharts.com/regional/no/daily/2019-11-15
# https://spotifycharts.com/regional/no/daily/2019-11-16
# https://spotifycharts.com/regional/no/daily/2019-11-17
# https://spotifycharts.com/regional/no/daily/2019-11-18
# https://spotifycharts.com/regional/no/daily/2019-11-19
# https://spotifycharts.com/regional/no/daily/2019-11-20
# https://spotifycharts.com/regional/no/daily/2019-11-21
# https://spotifycharts.com/regional/no/daily/2019-11-22
# https://spotifycharts.com/regional/no/daily/2019-11-23
# https://spotifycharts.com/regional/no/daily/2019-11-24
# https://spotifycharts.com/regional/no/daily/2019-11-25
# https://spotifycharts.com/regional/no/daily/2019-11-26
# https://spotifycharts.com/regional/no/daily/2019-11-27
# https://spotifycharts.com/regional/no/daily/2019-11-28
# https://spotifycharts.com/regional/no/daily/2019-11-29
# https://spotifycharts.com/regional/no/daily/2019-11-30
# https://spotifycharts.com/regional/no/daily/2019-12-01
# https://spotifycharts.com/regional/no/daily/2019-12-02
# https://spotifycharts.com/regional/no/daily/2019-12-03
# https://spotifycharts.com/regional/no/daily/2019-12-04
# https://spotifycharts.com/regional/no/daily/2019-12-05
# https://spotifycharts.com/regional/no/daily/2019-12-06
# https://spotifycharts.com/regional/no/daily/2019-12-07
# https://spotifycharts.com/regional/no/daily/2019-12-08
# https://spotifycharts.com/regional/no/daily/2019-12-09
# https://spotifycharts.com/regional/no/daily/2019-12-10
# https://spotifycharts.com/regional/no/daily/2019-12-11
# https://spotifycharts.com/regional/no/daily/2019-12-12
# https://spotifycharts.com/regional/no/daily/2019-12-13
# https://spotifycharts.com/regional/no/daily/2019-12-14
# https://spotifycharts.com/regional/no/daily/2019-12-15
# https://spotifycharts.com/regional/no/daily/2019-12-16
# https://spotifycharts.com/regional/no/daily/2019-12-17
# https://spotifycharts.com/regional/no/daily/2019-12-18
# https://spotifycharts.com/regional/no/daily/2019-12-19
# https://spotifycharts.com/regional/no/daily/2019-12-20
# https://spotifycharts.com/regional/no/daily/2019-12-21
# https://spotifycharts.com/regional/no/daily/2019-12-22
# https://spotifycharts.com/regional/no/daily/2019-12-23
# https://spotifycharts.com/regional/no/daily/2019-12-24
# https://spotifycharts.com/regional/no/daily/2019-12-25
# https://spotifycharts.com/regional/no/daily/2019-12-26
# https://spotifycharts.com/regional/no/daily/2019-12-27
# https://spotifycharts.com/regional/no/daily/2019-12-28
# https://spotifycharts.com/regional/no/daily/2019-12-29
# https://spotifycharts.com/regional/no/daily/2019-12-30
#        position  streams       date  \
# 0             1    69663 2019-01-01
# 1             2    67916 2019-01-01
# 2             3    56131 2019-01-01
# 3             4    53922 2019-01-01
# 4             5    53118 2019-01-01
# ...         ...      ...        ...
# 18195        46    25397 2019-12-30
# 18196        47    25119 2019-12-30
# 18197        48    23253 2019-12-30
# 18198        49    22865 2019-12-30
# 18199        50    22380 2019-12-30
#
#                                                      url  \
# 0      https://open.spotify.com/track/25sgk305KZfyuqV...
# 1      https://open.spotify.com/track/6MWtB6iiXyIwun0...
# 2      https://open.spotify.com/track/0lG6QM1jjbbX5UU...
# 3      https://open.spotify.com/track/2VxeLyX666F8uXC...
# 4      https://open.spotify.com/track/0nrWZWkJM62ftQJ...
# ...                                                  ...
# 18195  https://open.spotify.com/track/285pBltuF7vW8Te...
# 18196  https://open.spotify.com/track/4AO1XhrgJczQ9bN...
# 18197  https://open.spotify.com/track/4QPEwDdOMhY7rNS...
# 18198  https://open.spotify.com/track/6TmkOBZ2UEQaIWR...
# 18199  https://open.spotify.com/track/6UelLqGlWMcVH1E...
#
#                                   track_name                      artist  \
# 0                           Sweet but Psycho                     Ava Max
# 1                                       Wow.                 Post Malone
# 2                               Lost Control         Alan Walker, Sorana
# 3                                    Shallow   Lady Gaga, Bradley Cooper
# 4                              Diamond Heart  Alan Walker, Sophia Somajo
# ...                                      ...                         ...
# 18195                           Lucid Dreams                  Juice WRLD
# 18196        WHAT TO DO? (feat. Don Toliver)      JACKBOYS, Travis Scott
# 18197  Own It (feat. Ed Sheeran & Burna Boy)                     Stormzy
# 18198                      Can I Be Forgiven                 Highasakite
# 18199                       Watermelon Sugar                Harry Styles
#
#       region
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
# ...      ...
# 18195     no
# 18196     no
# 18197     no
# 18198     no
# 18199     no
#
# [18200 rows x 7 columns]

# %% [markdown]
# We then saved each dataframe (which contained the daily top 50 songs that a country listened to for a year) as its own csv file. Below is again an example using Norway.

# %%
norway2019.to_csv('norway2020.csv')

# %% [markdown]
# Once all of the 20 countries had been put through our webscraper, we concatenated all of the csv files together. We did this for the top and bottom 10 happiest countries in 2020 to create the dataset `spotify2020`. We did this for the top and bottom 10 happiest countries in 2019 to create the dataset `spotify2019`.
#
# Shown below is how we created `spotify2020`. This code was run after we read in the country csv files that we created using the method shown above.

# %%
spotify2020=pd.DataFrame()
spotify2020=spotify2020.append(finland,ignore_index=True)
spotify2020=spotify2020.append(denmark,ignore_index=True)
spotify2020=spotify2020.append(switzerland,ignore_index=True)
spotify2020=spotify2020.append(iceland,ignore_index=True)
spotify2020=spotify2020.append(norway,ignore_index=True)
spotify2020=spotify2020.append(netherlands,ignore_index=True)
spotify2020=spotify2020.append(sweden,ignore_index=True)
spotify2020=spotify2020.append(newzealand,ignore_index=True)
spotify2020=spotify2020.append(austria,ignore_index=True)
spotify2020=spotify2020.append(canada,ignore_index=True)

# %% [markdown]
# After webscraping, we are left with a dataset for 2019 and a dataset for 2020 that contains the daily top 50 songs per country for the top and bottom 10 countries in regards to their happiness scores! Shown below to demonstrate is `spotify2020`.

# %%
spotify2020
# Out:
#         position  streams        date  \
# 0              1    39681  2020-01-01
# 1              2    31179  2020-01-01
# 2              3    30339  2020-01-01
# 3              4    30208  2020-01-01
# 4              5    28966  2020-01-01
# ...          ...      ...         ...
# 182445        46    58237  2020-12-30
# 182446        47    57657  2020-12-30
# 182447        48    57321  2020-12-30
# 182448        49    57003  2020-12-30
# 182449        50    54819  2020-12-30
#
#                                                       url  \
# 0       https://open.spotify.com/track/0tc8HGXosQDC8TT...
# 1       https://open.spotify.com/track/3eHkFrUUGYuwEgI...
# 2       https://open.spotify.com/track/4gEvvWYAF3yzv9h...
# 3       https://open.spotify.com/track/0sf12qNH5qcw8qp...
# 4       https://open.spotify.com/track/1rgnBhdG2JDFTbY...
# ...                                                   ...
# 182445  https://open.spotify.com/track/6f3Slt0GbA2bPZl...
# 182446  https://open.spotify.com/track/7kDUspsoYfLkWnZ...
# 182447  https://open.spotify.com/track/21jGcNKet2qwijl...
# 182448  https://open.spotify.com/track/0A1hoCfMLkiAgvh...
# 182449  https://open.spotify.com/track/0RiRZpuVRbi7oqR...
#
#                                            track_name                 artist  \
# 0                                           Hei rakas                   BEHM
# 1                                       Pintakaasulla                    JVG
# 2                                         Luota Muhun                    ibe
# 3                                     Blinding Lights             The Weeknd
# 4                                        Dance Monkey            Tones And I
# ...                                               ...                    ...
# 182445                                   The Business                 Tiësto
# 182446           my ex's best friend (with blackbear)      Machine Gun Kelly
# 182447                                        Circles            Post Malone
# 182448                                           Body    Megan Thee Stallion
# 182449  Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
#
#        region
# 0          fi
# 1          fi
# 2          fi
# 3          fi
# 4          fi
# ...       ...
# 182445     ca
# 182446     ca
# 182447     ca
# 182448     ca
# 182449     ca
#
# [182450 rows x 7 columns]

# %% [markdown]
# ### IV. Spotify API <a name="api"></a>

# %% [markdown]
# We used a package called `Spotipy` which aided us in our use of Spotify API. We import `spotipy` and other necessary packages below.

# %%
#Spotify API
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import seaborn as sns
from sklearn.linear_model import LinearRegression as lr
# Deleted Spotify Web Developer CID and Secret

# %% [markdown]
# Next we developed a function, `getunique(dataframe)` that would allow us to get the features of the daily top 50 songs that a country listens to. The API provides a score that provides a score for a song's danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, and tempo.
#
# We call `drop_duplicates()` on the dataframe in order to get around the limit to the number of calls we can make to the Spotify API; this makes sense to use since the top songs are not wildly different from day-to-day. We can only call `getunique(dataframe)` on unique songs and then merge the song feature information to all of the songs later.

# %%
def getunique(dataframe):
    '''
    creates a dataframe containing the audio features of songs, all scores, which are floats. These audio features are provided by the Spotify API.
    parameters: a dataframe with a 'url' column, which contains valid links to a song on Spotify.
    returns: a dataframe with the audio features as columns, the observations being
    ONLY for the unique songs in the provided dataframe. Because the dataframe contains several repeated songs,
    we will avoid calling the API on duplicated songs because we will get a "max entries error"
    '''
    audiofeatures=pd.DataFrame({'danceability':[], 'energy':[],'key':[], 'loudness':[], 'mode':[], 'speechiness':[],'acousticness':[], 'instrumentalness':[],'liveness':[], 'valence':[], 'tempo':[], 'type':[],'id':[], 'uri':[],'track_href':[], 'analysis_url':[], 'duration_ms':[], 'time_signature':[]})
    dataframe.drop_duplicates(subset ="track_name",
                     keep = 'first', inplace = True,) #drop duplicate songs
    dataframe=dataframe.reset_index(drop=True)

    for row in range(len(dataframe)):
            url=dataframe.loc[row,'url']
            sub=url.rindex('/')
            idurl=url[sub+1:]
            newrow=sp.audio_features(idurl)[0]
            audiofeatures=audiofeatures.append(newrow,ignore_index=True)
    audiofeatures['track_name']=dataframe['track_name']
    audiofeatures['happiness_score']=dataframe['happiness_score']
    audiofeatures['happiness_rank']=dataframe['happiness_rank']
    audiofeatures['country']=dataframe['country']
    return audiofeatures

# %% [markdown]
# Below we demonstrate the use of `getunique(dataframe)` on data from 2019. We pass `spotify2019` as the argument. We do the same for 2020, instead using the relevant dataframes for 2020 not 2019.

# %%
uniquesongs2019=getunique(spotify2019)

# %%
uniquesongs2020=getunique(spotify2020)

# %% [markdown]
# Next, we merge our the data we cleaned earlier regarding the happiness scores for the top and bottom countries in 2019. We merge this data to the dataframe on `country` as this information appears in both the `uniquesongs2019` and the `happy2019` dataset. We do the same for 2020.

# %%
uniquesongs2019=uniquesongs2019.merge(happy2019[['happiness_rank','country','happiness_score']], how="left",on='country')

# %%
uniquesongs2020=uniquesongs2019.merge(happy2020[['happiness_rank','country','happiness_score']], how="left",on='country')

# %% [markdown]
# Finally, we merge our dataframe that only contains unique songs, with the original dataframe. This leaves us with the dataframes that we use in our main analysis.

# %%
spotify2019=uniquesongs2019.merge(song[['danceability','track_name' ,'happiness_score', 'happiness_rank', 'energy', 'key', 'loudness', 'mode', 'speechiness',
'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'id', 'duration_ms']], how="left",on='track_name')

# %%
spotify2020=uniquesongs2020.merge(song[['danceability','track_name' ,'happiness_score', 'happiness_rank', 'energy', 'key', 'loudness', 'mode', 'speechiness',
'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'id', 'duration_ms']], how="left",on='track_name')

# %% [markdown]
# Shown below is our dataframe for 2019 that contains the happiness scores and the song feature information.

# %%
spotify2019
# Out:
#         position  streams        date  \
# 0              1    33717  2019-01-01
# 1              2    29651  2019-01-01
# 2              3    28329  2019-01-01
# 3              4    23977  2019-01-01
# 4              5    22435  2019-01-01
# ...          ...      ...         ...
# 363995        46     3427  2019-12-30
# 363996        47     3416  2019-12-30
# 363997        48     3413  2019-12-30
# 363998        49     3407  2019-12-30
# 363999        50     3385  2019-12-30
#
#                                                       url  \
# 0       https://open.spotify.com/track/6MWtB6iiXyIwun0...
# 1       https://open.spotify.com/track/25sgk305KZfyuqV...
# 2       https://open.spotify.com/track/4RYtaqxjDJUOY2G...
# 3       https://open.spotify.com/track/2rPE9A1vEgShuZx...
# 4       https://open.spotify.com/track/00WO1oBxZcj9aBo...
# ...                                                   ...
# 363995  https://open.spotify.com/track/3jjujdWJ72nww5e...
# 363996  https://open.spotify.com/track/72Yg5qdIqpTnXrN...
# 363997  https://open.spotify.com/track/6XHVuErjQ4XNm6n...
# 363998  https://open.spotify.com/track/7h0d2h0fUmzbs7z...
# 363999  https://open.spotify.com/track/57vxBYXtHMk6H1a...
#
#                                                track_name           artist  \
# 0                                                    Wow.      Post Malone
# 1                                        Sweet but Psycho          Ava Max
# 2                                            Harmaa Rinne  Teflon Brothers
# 3                                           thank u, next    Ariana Grande
# 4                                              Tavallinen      Keko Salata
# ...                                                   ...              ...
# 363995                                          Adore You     Harry Styles
# 363996                                              Dames            Biggy
# 363997                          No Guidance (feat. Drake)      Chris Brown
# 363998  HIGHEST IN THE ROOM (feat. ROSALÍA & Lil Baby)...     Travis Scott
# 363999                                          Heartless       The Weeknd
#
#        region       country  danceability  happiness_score  ...  loudness  \
# 0          fi       Finland         0.833            7.769  ...    -7.399
# 1          fi       Finland         0.719            7.769  ...    -4.724
# 2          fi       Finland         0.861            7.769  ...    -5.862
# 3          fi       Finland         0.724            7.769  ...    -5.642
# 4          fi       Finland         0.803            7.769  ...    -7.928
# ...       ...           ...           ...              ...  ...       ...
# 363995     za  South Africa         0.676            7.769  ...    -3.675
# 363996     za  South Africa         0.912            4.722  ...    -7.984
# 363997     za  South Africa         0.698            7.600  ...    -6.756
# 363998     za  South Africa         0.559            7.769  ...    -6.406
# 363999     za  South Africa         0.531            7.769  ...    -5.831
#
#         mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0        0.0       0.1780       0.16300          0.000002    0.1010    0.385
# 1        1.0       0.0476       0.06910          0.000000    0.1660    0.628
# 2        0.0       0.1650       0.04100          0.000000    0.1500    0.962
# 3        1.0       0.0658       0.28000          0.000000    0.1020    0.435
# 4        0.0       0.0564       0.67300          0.000010    0.1330    0.404
# ...      ...          ...           ...               ...       ...      ...
# 363995   1.0       0.0483       0.02370          0.000007    0.1020    0.569
# 363996   1.0       0.2260       0.10300          0.000006    0.3580    0.637
# 363997   0.0       0.1510       0.12300          0.000000    0.1550    0.137
# 363998   0.0       0.0346       0.05670          0.000000    0.0992    0.114
# 363999   0.0       0.1110       0.00632          0.000076    0.1170    0.198
#
#           tempo                      id  duration_ms
# 0        99.947  6MWtB6iiXyIwun0YzU6DFP     149520.0
# 1       133.002  25sgk305KZfyuqVBQIahim     187436.0
# 2       129.933  4RYtaqxjDJUOY2GrtkLTFf     170886.0
# 3       106.960  2rPE9A1vEgShuZxxzR2tZH     207333.0
# 4       112.964  00WO1oBxZcj9aBoeiODXDx     231791.0
# ...         ...                     ...          ...
# 363995   99.048  1M4qEo4HE3PRaCOM7EXNJq     207133.0
# 363996  122.024  72Yg5qdIqpTnXrNPEewglz     217879.0
# 363997   92.932  7FEwp8BavoEVE3AnxJDchc     260640.0
# 363998  153.131  7h0d2h0fUmzbs7zeFigJPn     244874.0
# 363999  169.954  57vxBYXtHMk6H1aD29V7PU     200080.0
#
# [364000 rows x 23 columns]

# %%
spotify2019.to_csv('spotify2019.csv')

# %%
spotify2020.to_csv('spotify2020.csv')
